# %% [markdown]
# ## Embedding 계층 구현
# 입력층과 가중치를 곱할 때 데이터의 개수가 많으면 그만큼 계산해야 하는 데이터양이 커짐
#
# 따라서 단어 ID에 해당하는 행을 추출하는 계층을 만드는 것

# %%
class Embedding:
    def __init__(self, W):
        self.params = [W]
        self.grads = [np.zeros_like(W)]
        self.idx = None
    
    def forward(self, idx):
        W, = self.params
        self.idx = idx
        out = W[idx]
        return out

    def backward(self, dout):
        dW, = self.grads
        dW[...] = 0

        # 1. for문 이용 방법
        for i, word_id in enumerate(self.idx):
            dW[word_id] += dout[i]
        
        # 2. numpy 내장 함수 이용 방법 (속도가 더 빠름)
        # np.dd.at(dW, self.idx, dout)

        return None

# %% [markdown]
# ## 네거티브 샘플링
# 1. 은닉층의 뉴런과 가중치 행렬의 곱
# 2. Softmax 계층의 계산
#
# 1, 2의 문제를 개선하기 위해 기존의 다중 분류 문제를 이진 분류 문제로 바꿈
#
# 즉, 출력층을 모든 단어들의 배열이 아닌 우리가 원하는 결과 단어가 맞을 확률로만 확인
#
# 또한 정답이 아닌 모든 단어에 대한 확률을 학습하는 것이 아닌 몇 개만 샘플링하여 학습, 이것이 네거티브 샘플링의 의미

# %%
import numpy as np

class EmbeddingDot:
    def __init__(self, W):
        self.embed = Embedding(W)
        self.params = self.embed.params
        self.grads = self.embed.grads
        self.cache = None

    def forward(self, h, idx):
        target_W = self.embed.forward(idx)
        out = np.sum(target_W * h, axis=1)

        self.cache = (h, target_W)
        return out
    
    def backward(self, dout):
        h, target_W = self.cache
        dout = dout.reshape(dout.shape[0], 1)

        dtarget_W = dout * h
        self.embed.backward(dtarget_W)
        dh = dout * target_W
        return dh

# %% [markdown]
# ## 네거티브 샘플링 구현

# %%
# coding: utf-8
import sys
sys.path.append('..')
import numpy as np
from common.layers import Embedding, SigmoidWithLoss
import collections


class EmbeddingDot:
    def __init__(self, W):
        self.embed = Embedding(W)
        self.params = self.embed.params
        self.grads = self.embed.grads
        self.cache = None

    def forward(self, h, idx):
        target_W = self.embed.forward(idx)
        out = np.sum(target_W * h, axis=1)

        self.cache = (h, target_W)
        return out

    def backward(self, dout):
        h, target_W = self.cache
        dout = dout.reshape(dout.shape[0], 1)

        dtarget_W = dout * h
        self.embed.backward(dtarget_W)
        dh = dout * target_W
        return dh


class UnigramSampler:
    def __init__(self, corpus, power, sample_size):
        self.sample_size = sample_size
        self.vocab_size = None
        self.word_p = None

        counts = collections.Counter()
        for word_id in corpus:
            counts[word_id] += 1

        vocab_size = len(counts)
        self.vocab_size = vocab_size

        self.word_p = np.zeros(vocab_size)
        for i in range(vocab_size):
            self.word_p[i] = counts[i]

        self.word_p = np.power(self.word_p, power)
        self.word_p /= np.sum(self.word_p)

    def get_negative_sample(self, target):
        batch_size = target.shape[0]

        if not GPU:
            negative_sample = np.zeros((batch_size, self.sample_size), dtype=np.int32)

            for i in range(batch_size):
                p = self.word_p.copy()
                target_idx = target[i]
                p[target_idx] = 0
                p /= p.sum()
                negative_sample[i, :] = np.random.choice(self.vocab_size, size=self.sample_size, replace=False, p=p)
        else:
            # GPU(cupy）로 계산할 때는 속도를 우선한다.
            # 부정적 예에 타깃이 포함될 수 있다.
            negative_sample = np.random.choice(self.vocab_size, size=(batch_size, self.sample_size),
                                               replace=True, p=self.word_p)

        return negative_sample


class NegativeSamplingLoss:
    def __init__(self, W, corpus, power=0.75, sample_size=5):
        self.sample_size = sample_size
        self.sampler = UnigramSampler(corpus, power, sample_size)
        self.loss_layers = [SigmoidWithLoss() for _ in range(sample_size + 1)]
        self.embed_dot_layers = [EmbeddingDot(W) for _ in range(sample_size + 1)]

        self.params, self.grads = [], []
        for layer in self.embed_dot_layers:
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, h, target):
        batch_size = target.shape[0]
        negative_sample = self.sampler.get_negative_sample(target)

        # 긍정적 예 순전파
        score = self.embed_dot_layers[0].forward(h, target)
        correct_label = np.ones(batch_size, dtype=np.int32)
        loss = self.loss_layers[0].forward(score, correct_label)

        # 부정적 예 순전파
        negative_label = np.zeros(batch_size, dtype=np.int32)
        for i in range(self.sample_size):
            negative_target = negative_sample[:, i]
            score = self.embed_dot_layers[1 + i].forward(h, negative_target)
            loss += self.loss_layers[1 + i].forward(score, negative_label)

        return loss

    def backward(self, dout=1):
        dh = 0
        for l0, l1 in zip(self.loss_layers, self.embed_dot_layers):
            dscore = l0.backward(dout)
            dh += l1.backward(dscore)

        return dh

# %% [markdown]
# ## CBOW 모델 구현

# %%
import sys
sys.path.append('..')
import numpy as np
from common.layers import Embedding

class CBOW:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size

        # 가중치 초기화
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(V, H).astype('f')

        # 계층 생성
        self.in_layers = []
        for i in range(2 * window_size):
            layer = Embedding(W_in)  # Embedding 계층 사용
            self.in_layers.append(layer)
        self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)

        # 모든 가중치와 기울기를 배열에 모은다.
        layers = self.in_layers + [self.ns_loss]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 인스턴스 변수에 단어의 분산 표현을 저장한다.
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = 0
        for i, layer in enumerate(self.in_layers):
            h += layer.forward(contexts[:, i])
        h *= 1 / len(self.in_layers)
        loss = self.ns_loss.forward(h, target)
        return loss
    
    def backward(self, dout=1):
        dout = self.ns_loss.backward(dout)
        dout *= 1 / len(self.in_layers)
        for layer in self.in_layers:
            layer.backward(dout)
        return None

# %% [markdown]
# ## CBOW 모델 학습 코드

# %%
import sys
sys.path.append('..')
import numpy as np
import pickle
from common.trainer import Trainer
from common.optimizer import Adam
from common.util import create_contexts_target, to_cpu, to_gpu
from dataset import ptb

# 하이퍼파라미터 설정
window_size = 5
hidden_size = 100
batch_size = 100
max_epoch = 10
GPU = False

# 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)

contexts, target = create_contexts_target(corpus, window_size)

# 모델 등 생성
model = CBOW(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 학습 시작
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 나중에 사용할 수 있도록 필요한 데이터 저장
word_vecs = model.word_vecs
params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# | 에폭 1 |  반복 1 / 9295 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 21 / 9295 | 시간 1[s] | 손실 4.16
# | 에폭 1 |  반복 41 / 9295 | 시간 2[s] | 손실 4.15
# | 에폭 1 |  반복 61 / 9295 | 시간 3[s] | 손실 4.12
# | 에폭 1 |  반복 81 / 9295 | 시간 4[s] | 손실 4.04
# | 에폭 1 |  반복 101 / 9295 | 시간 5[s] | 손실 3.92
# | 에폭 1 |  반복 121 / 9295 | 시간 6[s] | 손실 3.77
# | 에폭 1 |  반복 141 / 9295 | 시간 7[s] | 손실 3.62
# | 에폭 1 |  반복 161 / 9295 | 시간 8[s] | 손실 3.48
# | 에폭 1 |  반복 181 / 9295 | 시간 9[s] | 손실 3.36
# | 에폭 1 |  반복 201 / 9295 | 시간 10[s] | 손실 3.27
# | 에폭 1 |  반복 221 / 9295 | 시간 11[s] | 손실 3.15
# | 에폭 1 |  반복 241 / 9295 | 시간 13[s] | 손실 3.08
# | 에폭 1 |  반복 261 / 9295 | 시간 14[s] | 손실 3.01
# | 에폭 1 |  반복 281 / 9295 | 시간 15[s] | 손실 2.96
# | 에폭 1 |  반복 301 / 9295 | 시간 16[s] | 손실 2.91
# | 에폭 1 |  반복 321 / 9295 | 시간 17[s] | 손실 2.89
# | 에폭 1 |  반복 341 / 9295 | 시간 18[s] | 손실 2.84
# | 에폭 1 |  반복 361 / 9295 | 시간 19[s] | 손실 2.81
# | 에폭 1 |  반복 381 / 9295 | 시간 20[s] | 손실 2.79
# | 에폭 1 |  반복 401 / 9295 | 시간 21[s] | 손실 2.79
# | 에폭 1 |  반복 421 / 9295 | 시간 22[s] | 손실 2.72
# | 에폭 1 |  반복 441 / 9295 | 시간 23[s] | 손실 2.74
# | 에폭 1 |  반복 461 / 9295 | 시간 24[s] | 손실 2.70
# | 에폭 1 |  반복 481 / 9295 | 시간 25[s] | 손실 2.72
# | 에폭 1 |  반복 501 / 9295 | 시간 27[s] | 손실 2.70
# | 에폭 1 |  반복 521 / 9295 | 시간 28[s] | 손실 2.70
# | 에폭 1 |  반복 541 / 9295 | 시간 29[s] | 손실 2.68
# | 에폭 1 |  반복 561 / 9295 | 시간 30[s] | 손실 2.65
# | 에폭 1 |  반복 581 / 9295 | 시간 31[s] | 손실 2.65
# | 에폭 1 |  반복 601 / 9295 | 시간 32[s] | 손실 2.63
# | 에폭 1 |  반복 621 / 9295 | 시간 33[s] | 손실 2.64
# | 에폭 1 |  반복 641 / 9295 | 시간 34[s] | 손실 2.65
# | 에폭 1 |  반복 661 / 9295 | 시간 35[s] | 손실 2.64
# | 에폭 1 |  반복 681 / 9295 | 시간 36[s] | 손실 2.64
# | 에폭 1 |  반복 701 / 9295 | 시간 37[s] | 손실 2.61
# | 에폭 1 |  반복 721 / 9295 | 시간 38[s] | 손실 2.59
# | 에폭 1 |  반복 741 / 9295 | 시간 39[s] | 손실 2.59
# | 에폭 1 |  반복 761 / 9295 | 시간 40[s] | 손실 2.60
# | 에폭 1 |  반복 781 / 9295 | 시간 42[s] | 손실 2.60
# | 에폭 1 |  반복 801 / 9295 | 시간 43[s] | 손실 2.59
# | 에폭 1 |  반복 821 / 9295 | 시간 44[s] | 손실 2.59
# | 에폭 1 |  반복 841 / 9295 | 시간 45[s] | 손실 2.57
# | 에폭 1 |  반복 861 / 9295 | 시간 46[s] | 손실 2.59
# | 에폭 1 |  반복 881 / 9295 | 시간 47[s] | 손실 2.57
# | 에폭 1 |  반복 901 / 9295 | 시간 48[s] | 손실 2.58
# | 에폭 1 |  반복 921 / 9295 | 시간 49[s] | 손실 2.57
# | 에폭 1 |  반복 941 / 9295 | 시간 50[s] | 손실 2.58
# | 에폭 1 |  반복 961 / 9295 | 시간 51[s] | 손실 2.55
# | 에폭 1 |  반복 981 / 9295 | 시간 52[s] | 손실 2.58
# | 에폭 1 |  반복 1001 / 9295 | 시간 53[s] | 손실 2.54
# | 에폭 1 |  반복 1021 / 9295 | 시간 54[s] | 손실 2.56
# | 에폭 1 |  반복 1041 / 9295 | 시간 55[s] | 손실 2.56
# | 에폭 1 |  반복 1061 / 9295 | 시간 56[s] | 손실 2.56
# | 에폭 1 |  반복 1081 / 9295 | 시간 57[s] | 손실 2.56
# | 에폭 1 |  반복 1101 / 9295 | 시간 59[s] | 손실 2.56
# | 에폭 1 |  반복 1121 / 9295 | 시간 60[s] | 손실 2.54
# | 에폭 1 |  반복 1141 / 9295 | 시간 61[s] | 손실 2.54
# | 에폭 1 |  반복 1161 / 9295 | 시간 62[s] | 손실 2.52
# | 에폭 1 |  반복 1181 / 9295 | 시간 63[s] | 손실 2.54
# | 에폭 1 |  반복 1201 / 9295 | 시간 64[s] | 손실 2.54
# | 에폭 1 |  반복 1221 / 9295 | 시간 65[s] | 손실 2.55
# | 에폭 1 |  반복 1241 / 9295 | 시간 66[s] | 손실 2.53
# | 에폭 1 |  반복 1261 / 9295 | 시간 67[s] | 손실 2.55
# | 에폭 1 |  반복 1281 / 9295 | 시간 68[s] | 손실 2.52
# | 에폭 1 |  반복 1301 / 9295 | 시간 69[s] | 손실 2.53
# | 에폭 1 |  반복 1321 / 9295 | 시간 70[s] | 손실 2.54
# | 에폭 1 |  반복 1341 / 9295 | 시간 71[s] | 손실 2.51
# | 에폭 1 |  반복 1361 / 9295 | 시간 72[s] | 손실 2.51
# | 에폭 1 |  반복 1381 / 9295 | 시간 73[s] | 손실 2.54
# | 에폭 1 |  반복 1401 / 9295 | 시간 74[s] | 손실 2.54
# | 에폭 1 |  반복 1421 / 9295 | 시간 76[s] | 손실 2.52
# | 에폭 1 |  반복 1441 / 9295 | 시간 77[s] | 손실 2.51
# | 에폭 1 |  반복 1461 / 9295 | 시간 78[s] | 손실 2.53
# | 에폭 1 |  반복 1481 / 9295 | 시간 79[s] | 손실 2.49
# | 에폭 1 |  반복 1501 / 9295 | 시간 80[s] | 손실 2.51
# | 에폭 1 |  반복 1521 / 9295 | 시간 81[s] | 손실 2.54
# | 에폭 1 |  반복 1541 / 9295 | 시간 82[s] | 손실 2.50
# | 에폭 1 |  반복 1561 / 9295 | 시간 83[s] | 손실 2.52
# | 에폭 1 |  반복 1581 / 9295 | 시간 84[s] | 손실 2.53
# | 에폭 1 |  반복 1601 / 9295 | 시간 85[s] | 손실 2.52
# | 에폭 1 |  반복 1621 / 9295 | 시간 86[s] | 손실 2.49
# | 에폭 1 |  반복 1641 / 9295 | 시간 87[s] | 손실 2.47
# | 에폭 1 |  반복 1661 / 9295 | 시간 88[s] | 손실 2.52
# | 에폭 1 |  반복 1681 / 9295 | 시간 89[s] | 손실 2.50
# | 에폭 1 |  반복 1701 / 9295 | 시간 90[s] | 손실 2.47
# | 에폭 1 |  반복 1721 / 9295 | 시간 91[s] | 손실 2.53
# | 에폭 1 |  반복 1741 / 9295 | 시간 93[s] | 손실 2.51
# | 에폭 1 |  반복 1761 / 9295 | 시간 94[s] | 손실 2.50
# | 에폭 1 |  반복 1781 / 9295 | 시간 95[s] | 손실 2.49
# | 에폭 1 |  반복 1801 / 9295 | 시간 96[s] | 손실 2.50
# | 에폭 1 |  반복 1821 / 9295 | 시간 97[s] | 손실 2.50
# | 에폭 1 |  반복 1841 / 9295 | 시간 98[s] | 손실 2.52
# | 에폭 1 |  반복 1861 / 9295 | 시간 99[s] | 손실 2.50
# | 에폭 1 |  반복 1881 / 9295 | 시간 100[s] | 손실 2.50
# | 에폭 1 |  반복 1901 / 9295 | 시간 101[s] | 손실 2.48
# | 에폭 1 |  반복 1921 / 9295 | 시간 102[s] | 손실 2.49
# | 에폭 1 |  반복 1941 / 9295 | 시간 103[s] | 손실 2.50
# | 에폭 1 |  반복 1961 / 9295 | 시간 104[s] | 손실 2.53
# | 에폭 1 |  반복 1981 / 9295 | 시간 105[s] | 손실 2.50
# | 에폭 1 |  반복 2001 / 9295 | 시간 107[s] | 손실 2.48
# | 에폭 1 |  반복 2021 / 9295 | 시간 108[s] | 손실 2.48
# | 에폭 1 |  반복 2041 / 9295 | 시간 109[s] | 손실 2.48
# | 에폭 1 |  반복 2061 / 9295 | 시간 110[s] | 손실 2.47
# | 에폭 1 |  반복 2081 / 9295 | 시간 111[s] | 손실 2.50
# | 에폭 1 |  반복 2101 / 9295 | 시간 112[s] | 손실 2.50
# | 에폭 1 |  반복 2121 / 9295 | 시간 113[s] | 손실 2.52
# | 에폭 1 |  반복 2141 / 9295 | 시간 114[s] | 손실 2.47
# | 에폭 1 |  반복 2161 / 9295 | 시간 115[s] | 손실 2.47
# | 에폭 1 |  반복 2181 / 9295 | 시간 116[s] | 손실 2.44
# | 에폭 1 |  반복 2201 / 9295 | 시간 118[s] | 손실 2.47
# | 에폭 1 |  반복 2221 / 9295 | 시간 119[s] | 손실 2.49
# | 에폭 1 |  반복 2241 / 9295 | 시간 120[s] | 손실 2.47
# | 에폭 1 |  반복 2261 / 9295 | 시간 121[s] | 손실 2.51
# | 에폭 1 |  반복 2281 / 9295 | 시간 122[s] | 손실 2.50
# | 에폭 1 |  반복 2301 / 9295 | 시간 123[s] | 손실 2.47
# | 에폭 1 |  반복 2321 / 9295 | 시간 124[s] | 손실 2.45
# | 에폭 1 |  반복 2341 / 9295 | 시간 125[s] | 손실 2.45
# | 에폭 1 |  반복 2361 / 9295 | 시간 126[s] | 손실 2.43
# | 에폭 1 |  반복 2381 / 9295 | 시간 127[s] | 손실 2.44
# | 에폭 1 |  반복 2401 / 9295 | 시간 128[s] | 손실 2.47
# | 에폭 1 |  반복 2421 / 9295 | 시간 130[s] | 손실 2.47
# | 에폭 1 |  반복 2441 / 9295 | 시간 131[s] | 손실 2.46
# | 에폭 1 |  반복 2461 / 9295 | 시간 132[s] | 손실 2.45
# | 에폭 1 |  반복 2481 / 9295 | 시간 133[s] | 손실 2.45
# | 에폭 1 |  반복 2501 / 9295 | 시간 134[s] | 손실 2.48
# | 에폭 1 |  반복 2521 / 9295 | 시간 135[s] | 손실 2.46
# | 에폭 1 |  반복 2541 / 9295 | 시간 136[s] | 손실 2.46
# | 에폭 1 |  반복 2561 / 9295 | 시간 137[s] | 손실 2.50
# | 에폭 1 |  반복 2581 / 9295 | 시간 138[s] | 손실 2.46
# | 에폭 1 |  반복 2601 / 9295 | 시간 140[s] | 손실 2.45
# | 에폭 1 |  반복 2621 / 9295 | 시간 141[s] | 손실 2.48
# | 에폭 1 |  반복 2641 / 9295 | 시간 142[s] | 손실 2.51
# | 에폭 1 |  반복 2661 / 9295 | 시간 143[s] | 손실 2.45
# | 에폭 1 |  반복 2681 / 9295 | 시간 144[s] | 손실 2.45
# | 에폭 1 |  반복 2701 / 9295 | 시간 145[s] | 손실 2.48
# | 에폭 1 |  반복 2721 / 9295 | 시간 146[s] | 손실 2.44
# | 에폭 1 |  반복 2741 / 9295 | 시간 147[s] | 손실 2.43
# | 에폭 1 |  반복 2761 / 9295 | 시간 148[s] | 손실 2.45
# | 에폭 1 |  반복 2781 / 9295 | 시간 149[s] | 손실 2.47
# | 에폭 1 |  반복 2801 / 9295 | 시간 150[s] | 손실 2.46
# | 에폭 1 |  반복 2821 / 9295 | 시간 151[s] | 손실 2.45
# | 에폭 1 |  반복 2841 / 9295 | 시간 153[s] | 손실 2.42
# | 에폭 1 |  반복 2861 / 9295 | 시간 154[s] | 손실 2.43
# | 에폭 1 |  반복 2881 / 9295 | 시간 155[s] | 손실 2.45
# | 에폭 1 |  반복 2901 / 9295 | 시간 156[s] | 손실 2.45
# | 에폭 1 |  반복 2921 / 9295 | 시간 157[s] | 손실 2.44
# | 에폭 1 |  반복 2941 / 9295 | 시간 158[s] | 손실 2.43
# | 에폭 1 |  반복 2961 / 9295 | 시간 159[s] | 손실 2.45
# | 에폭 1 |  반복 2981 / 9295 | 시간 160[s] | 손실 2.44
# | 에폭 1 |  반복 3001 / 9295 | 시간 161[s] | 손실 2.47
# | 에폭 1 |  반복 3021 / 9295 | 시간 162[s] | 손실 2.42
# | 에폭 1 |  반복 3041 / 9295 | 시간 163[s] | 손실 2.45
# | 에폭 1 |  반복 3061 / 9295 | 시간 164[s] | 손실 2.45
# | 에폭 1 |  반복 3081 / 9295 | 시간 166[s] | 손실 2.46
# | 에폭 1 |  반복 3101 / 9295 | 시간 167[s] | 손실 2.46
# | 에폭 1 |  반복 3121 / 9295 | 시간 168[s] | 손실 2.44
# | 에폭 1 |  반복 3141 / 9295 | 시간 169[s] | 손실 2.45
# | 에폭 1 |  반복 3161 / 9295 | 시간 170[s] | 손실 2.44
# | 에폭 1 |  반복 3181 / 9295 | 시간 171[s] | 손실 2.43
# | 에폭 1 |  반복 3201 / 9295 | 시간 172[s] | 손실 2.43
# | 에폭 1 |  반복 3221 / 9295 | 시간 173[s] | 손실 2.43
# | 에폭 1 |  반복 3241 / 9295 | 시간 174[s] | 손실 2.42
# | 에폭 1 |  반복 3261 / 9295 | 시간 175[s] | 손실 2.44
# | 에폭 1 |  반복 3281 / 9295 | 시간 176[s] | 손실 2.43
# | 에폭 1 |  반복 3301 / 9295 | 시간 178[s] | 손실 2.45
# | 에폭 1 |  반복 3321 / 9295 | 시간 179[s] | 손실 2.47
# | 에폭 1 |  반복 3341 / 9295 | 시간 180[s] | 손실 2.45
# | 에폭 1 |  반복 3361 / 9295 | 시간 181[s] | 손실 2.43
# | 에폭 1 |  반복 3381 / 9295 | 시간 182[s] | 손실 2.44
# | 에폭 1 |  반복 3401 / 9295 | 시간 183[s] | 손실 2.43
# | 에폭 1 |  반복 3421 / 9295 | 시간 184[s] | 손실 2.45
# | 에폭 1 |  반복 3441 / 9295 | 시간 185[s] | 손실 2.42
# | 에폭 1 |  반복 3461 / 9295 | 시간 186[s] | 손실 2.43
# | 에폭 1 |  반복 3481 / 9295 | 시간 187[s] | 손실 2.43
# | 에폭 1 |  반복 3501 / 9295 | 시간 188[s] | 손실 2.41
# | 에폭 1 |  반복 3521 / 9295 | 시간 190[s] | 손실 2.44
# | 에폭 1 |  반복 3541 / 9295 | 시간 191[s] | 손실 2.43
# | 에폭 1 |  반복 3561 / 9295 | 시간 192[s] | 손실 2.40
# | 에폭 1 |  반복 3581 / 9295 | 시간 193[s] | 손실 2.44
# | 에폭 1 |  반복 3601 / 9295 | 시간 194[s] | 손실 2.40
# | 에폭 1 |  반복 3621 / 9295 | 시간 195[s] | 손실 2.45
# | 에폭 1 |  반복 3641 / 9295 | 시간 196[s] | 손실 2.44
# | 에폭 1 |  반복 3661 / 9295 | 시간 197[s] | 손실 2.42
# | 에폭 1 |  반복 3681 / 9295 | 시간 198[s] | 손실 2.41
# | 에폭 1 |  반복 3701 / 9295 | 시간 199[s] | 손실 2.42
# | 에폭 1 |  반복 3721 / 9295 | 시간 200[s] | 손실 2.42
# | 에폭 1 |  반복 3741 / 9295 | 시간 202[s] | 손실 2.44
# | 에폭 1 |  반복 3761 / 9295 | 시간 203[s] | 손실 2.42
# | 에폭 1 |  반복 3781 / 9295 | 시간 204[s] | 손실 2.43
# | 에폭 1 |  반복 3801 / 9295 | 시간 205[s] | 손실 2.41
# | 에폭 1 |  반복 3821 / 9295 | 시간 206[s] | 손실 2.41
# | 에폭 1 |  반복 3841 / 9295 | 시간 207[s] | 손실 2.41
# | 에폭 1 |  반복 3861 / 9295 | 시간 208[s] | 손실 2.42
# | 에폭 1 |  반복 3881 / 9295 | 시간 209[s] | 손실 2.36
# | 에폭 1 |  반복 3901 / 9295 | 시간 210[s] | 손실 2.44
# | 에폭 1 |  반복 3921 / 9295 | 시간 211[s] | 손실 2.38
# | 에폭 1 |  반복 3941 / 9295 | 시간 212[s] | 손실 2.41
# | 에폭 1 |  반복 3961 / 9295 | 시간 214[s] | 손실 2.41
# | 에폭 1 |  반복 3981 / 9295 | 시간 215[s] | 손실 2.42
# | 에폭 1 |  반복 4001 / 9295 | 시간 216[s] | 손실 2.42
# | 에폭 1 |  반복 4021 / 9295 | 시간 217[s] | 손실 2.39
# | 에폭 1 |  반복 4041 / 9295 | 시간 218[s] | 손실 2.38
# | 에폭 1 |  반복 4061 / 9295 | 시간 219[s] | 손실 2.40
# | 에폭 1 |  반복 4081 / 9295 | 시간 220[s] | 손실 2.40
# | 에폭 1 |  반복 4101 / 9295 | 시간 221[s] | 손실 2.37
# | 에폭 1 |  반복 4121 / 9295 | 시간 222[s] | 손실 2.40
# | 에폭 1 |  반복 4141 / 9295 | 시간 223[s] | 손실 2.43
# | 에폭 1 |  반복 4161 / 9295 | 시간 225[s] | 손실 2.42
# | 에폭 1 |  반복 4181 / 9295 | 시간 226[s] | 손실 2.40
# | 에폭 1 |  반복 4201 / 9295 | 시간 227[s] | 손실 2.41
# | 에폭 1 |  반복 4221 / 9295 | 시간 228[s] | 손실 2.39
# | 에폭 1 |  반복 4241 / 9295 | 시간 229[s] | 손실 2.40
# | 에폭 1 |  반복 4261 / 9295 | 시간 230[s] | 손실 2.41
# | 에폭 1 |  반복 4281 / 9295 | 시간 231[s] | 손실 2.40
# | 에폭 1 |  반복 4301 / 9295 | 시간 232[s] | 손실 2.42
# | 에폭 1 |  반복 4321 / 9295 | 시간 233[s] | 손실 2.38
# | 에폭 1 |  반복 4341 / 9295 | 시간 235[s] | 손실 2.38
# | 에폭 1 |  반복 4361 / 9295 | 시간 236[s] | 손실 2.40
# | 에폭 1 |  반복 4381 / 9295 | 시간 237[s] | 손실 2.40
# | 에폭 1 |  반복 4401 / 9295 | 시간 238[s] | 손실 2.40
# | 에폭 1 |  반복 4421 / 9295 | 시간 239[s] | 손실 2.37
# | 에폭 1 |  반복 4441 / 9295 | 시간 240[s] | 손실 2.42
# | 에폭 1 |  반복 4461 / 9295 | 시간 241[s] | 손실 2.35
# | 에폭 1 |  반복 4481 / 9295 | 시간 242[s] | 손실 2.38
# | 에폭 1 |  반복 4501 / 9295 | 시간 243[s] | 손실 2.37
# | 에폭 1 |  반복 4521 / 9295 | 시간 244[s] | 손실 2.40
# | 에폭 1 |  반복 4541 / 9295 | 시간 245[s] | 손실 2.40
# | 에폭 1 |  반복 4561 / 9295 | 시간 246[s] | 손실 2.39
# | 에폭 1 |  반복 4581 / 9295 | 시간 247[s] | 손실 2.36
# | 에폭 1 |  반복 4601 / 9295 | 시간 249[s] | 손실 2.37
# | 에폭 1 |  반복 4621 / 9295 | 시간 250[s] | 손실 2.39
# | 에폭 1 |  반복 4641 / 9295 | 시간 251[s] | 손실 2.37
# | 에폭 1 |  반복 4661 / 9295 | 시간 252[s] | 손실 2.40
# | 에폭 1 |  반복 4681 / 9295 | 시간 253[s] | 손실 2.40
# | 에폭 1 |  반복 4701 / 9295 | 시간 254[s] | 손실 2.38
# | 에폭 1 |  반복 4721 / 9295 | 시간 255[s] | 손실 2.36
# | 에폭 1 |  반복 4741 / 9295 | 시간 256[s] | 손실 2.36
# | 에폭 1 |  반복 4761 / 9295 | 시간 257[s] | 손실 2.40
# | 에폭 1 |  반복 4781 / 9295 | 시간 258[s] | 손실 2.39
# | 에폭 1 |  반복 4801 / 9295 | 시간 259[s] | 손실 2.36
# | 에폭 1 |  반복 4821 / 9295 | 시간 260[s] | 손실 2.36
# | 에폭 1 |  반복 4841 / 9295 | 시간 261[s] | 손실 2.36
# | 에폭 1 |  반복 4861 / 9295 | 시간 262[s] | 손실 2.32
# | 에폭 1 |  반복 4881 / 9295 | 시간 263[s] | 손실 2.39
# | 에폭 1 |  반복 4901 / 9295 | 시간 265[s] | 손실 2.38
# | 에폭 1 |  반복 4921 / 9295 | 시간 266[s] | 손실 2.34
# | 에폭 1 |  반복 4941 / 9295 | 시간 267[s] | 손실 2.38
# | 에폭 1 |  반복 4961 / 9295 | 시간 268[s] | 손실 2.37
# | 에폭 1 |  반복 4981 / 9295 | 시간 269[s] | 손실 2.36
# | 에폭 1 |  반복 5001 / 9295 | 시간 270[s] | 손실 2.40
# | 에폭 1 |  반복 5021 / 9295 | 시간 271[s] | 손실 2.33
# | 에폭 1 |  반복 5041 / 9295 | 시간 272[s] | 손실 2.38
# | 에폭 1 |  반복 5061 / 9295 | 시간 273[s] | 손실 2.38
# | 에폭 1 |  반복 5081 / 9295 | 시간 274[s] | 손실 2.32
# | 에폭 1 |  반복 5101 / 9295 | 시간 275[s] | 손실 2.32
# | 에폭 1 |  반복 5121 / 9295 | 시간 276[s] | 손실 2.33
# | 에폭 1 |  반복 5141 / 9295 | 시간 277[s] | 손실 2.35
# | 에폭 1 |  반복 5161 / 9295 | 시간 278[s] | 손실 2.34
# | 에폭 1 |  반복 5181 / 9295 | 시간 279[s] | 손실 2.34
# | 에폭 1 |  반복 5201 / 9295 | 시간 281[s] | 손실 2.38
# | 에폭 1 |  반복 5221 / 9295 | 시간 282[s] | 손실 2.38
# | 에폭 1 |  반복 5241 / 9295 | 시간 283[s] | 손실 2.35
# | 에폭 1 |  반복 5261 / 9295 | 시간 284[s] | 손실 2.37
# | 에폭 1 |  반복 5281 / 9295 | 시간 285[s] | 손실 2.35
# | 에폭 1 |  반복 5301 / 9295 | 시간 286[s] | 손실 2.32
# | 에폭 1 |  반복 5321 / 9295 | 시간 287[s] | 손실 2.35
# | 에폭 1 |  반복 5341 / 9295 | 시간 288[s] | 손실 2.38
# | 에폭 1 |  반복 5361 / 9295 | 시간 289[s] | 손실 2.36
# | 에폭 1 |  반복 5381 / 9295 | 시간 290[s] | 손실 2.31
# | 에폭 1 |  반복 5401 / 9295 | 시간 291[s] | 손실 2.34
# | 에폭 1 |  반복 5421 / 9295 | 시간 292[s] | 손실 2.34
# | 에폭 1 |  반복 5441 / 9295 | 시간 293[s] | 손실 2.34
# | 에폭 1 |  반복 5461 / 9295 | 시간 294[s] | 손실 2.32
# | 에폭 1 |  반복 5481 / 9295 | 시간 295[s] | 손실 2.33
# | 에폭 1 |  반복 5501 / 9295 | 시간 297[s] | 손실 2.34
# | 에폭 1 |  반복 5521 / 9295 | 시간 298[s] | 손실 2.31
# | 에폭 1 |  반복 5541 / 9295 | 시간 299[s] | 손실 2.34
# | 에폭 1 |  반복 5561 / 9295 | 시간 300[s] | 손실 2.32
# | 에폭 1 |  반복 5581 / 9295 | 시간 301[s] | 손실 2.33
# | 에폭 1 |  반복 5601 / 9295 | 시간 302[s] | 손실 2.35
# | 에폭 1 |  반복 5621 / 9295 | 시간 303[s] | 손실 2.33
# | 에폭 1 |  반복 5641 / 9295 | 시간 304[s] | 손실 2.33
# | 에폭 1 |  반복 5661 / 9295 | 시간 305[s] | 손실 2.32
# | 에폭 1 |  반복 5681 / 9295 | 시간 306[s] | 손실 2.34
# | 에폭 1 |  반복 5701 / 9295 | 시간 307[s] | 손실 2.33
# | 에폭 1 |  반복 5721 / 9295 | 시간 308[s] | 손실 2.36
# | 에폭 1 |  반복 5741 / 9295 | 시간 309[s] | 손실 2.35
# | 에폭 1 |  반복 5761 / 9295 | 시간 310[s] | 손실 2.36
# | 에폭 1 |  반복 5781 / 9295 | 시간 312[s] | 손실 2.33
# | 에폭 1 |  반복 5801 / 9295 | 시간 313[s] | 손실 2.31
# | 에폭 1 |  반복 5821 / 9295 | 시간 314[s] | 손실 2.35
# | 에폭 1 |  반복 5841 / 9295 | 시간 315[s] | 손실 2.36
# | 에폭 1 |  반복 5861 / 9295 | 시간 316[s] | 손실 2.34
# | 에폭 1 |  반복 5881 / 9295 | 시간 317[s] | 손실 2.33
# | 에폭 1 |  반복 5901 / 9295 | 시간 318[s] | 손실 2.33
# | 에폭 1 |  반복 5921 / 9295 | 시간 319[s] | 손실 2.35
# | 에폭 1 |  반복 5941 / 9295 | 시간 320[s] | 손실 2.32
# | 에폭 1 |  반복 5961 / 9295 | 시간 321[s] | 손실 2.31
# | 에폭 1 |  반복 5981 / 9295 | 시간 322[s] | 손실 2.31
# | 에폭 1 |  반복 6001 / 9295 | 시간 323[s] | 손실 2.32
# | 에폭 1 |  반복 6021 / 9295 | 시간 324[s] | 손실 2.32
# | 에폭 1 |  반복 6041 / 9295 | 시간 325[s] | 손실 2.34
# | 에폭 1 |  반복 6061 / 9295 | 시간 326[s] | 손실 2.37
# | 에폭 1 |  반복 6081 / 9295 | 시간 328[s] | 손실 2.35
# | 에폭 1 |  반복 6101 / 9295 | 시간 329[s] | 손실 2.32
# | 에폭 1 |  반복 6121 / 9295 | 시간 330[s] | 손실 2.30
# | 에폭 1 |  반복 6141 / 9295 | 시간 331[s] | 손실 2.36
# | 에폭 1 |  반복 6161 / 9295 | 시간 332[s] | 손실 2.30
# | 에폭 1 |  반복 6181 / 9295 | 시간 333[s] | 손실 2.33
# | 에폭 1 |  반복 6201 / 9295 | 시간 334[s] | 손실 2.31
# | 에폭 1 |  반복 6221 / 9295 | 시간 335[s] | 손실 2.34
# | 에폭 1 |  반복 6241 / 9295 | 시간 336[s] | 손실 2.34
# | 에폭 1 |  반복 6261 / 9295 | 시간 337[s] | 손실 2.32
# | 에폭 1 |  반복 6281 / 9295 | 시간 338[s] | 손실 2.33
# | 에폭 1 |  반복 6301 / 9295 | 시간 339[s] | 손실 2.32
# | 에폭 1 |  반복 6321 / 9295 | 시간 340[s] | 손실 2.31
# | 에폭 1 |  반복 6341 / 9295 | 시간 341[s] | 손실 2.30
# | 에폭 1 |  반복 6361 / 9295 | 시간 342[s] | 손실 2.29
# | 에폭 1 |  반복 6381 / 9295 | 시간 344[s] | 손실 2.31
# | 에폭 1 |  반복 6401 / 9295 | 시간 345[s] | 손실 2.29
# | 에폭 1 |  반복 6421 / 9295 | 시간 346[s] | 손실 2.30
# | 에폭 1 |  반복 6441 / 9295 | 시간 347[s] | 손실 2.32
# | 에폭 1 |  반복 6461 / 9295 | 시간 348[s] | 손실 2.33
# | 에폭 1 |  반복 6481 / 9295 | 시간 349[s] | 손실 2.30
# | 에폭 1 |  반복 6501 / 9295 | 시간 350[s] | 손실 2.29
# | 에폭 1 |  반복 6521 / 9295 | 시간 351[s] | 손실 2.31
# | 에폭 1 |  반복 6541 / 9295 | 시간 352[s] | 손실 2.28
# | 에폭 1 |  반복 6561 / 9295 | 시간 353[s] | 손실 2.31
# | 에폭 1 |  반복 6581 / 9295 | 시간 354[s] | 손실 2.29
# | 에폭 1 |  반복 6601 / 9295 | 시간 355[s] | 손실 2.31
# | 에폭 1 |  반복 6621 / 9295 | 시간 356[s] | 손실 2.31
# | 에폭 1 |  반복 6641 / 9295 | 시간 357[s] | 손실 2.32
# | 에폭 1 |  반복 6661 / 9295 | 시간 358[s] | 손실 2.30
# | 에폭 1 |  반복 6681 / 9295 | 시간 360[s] | 손실 2.31
# | 에폭 1 |  반복 6701 / 9295 | 시간 361[s] | 손실 2.32
# | 에폭 1 |  반복 6721 / 9295 | 시간 362[s] | 손실 2.25
# | 에폭 1 |  반복 6741 / 9295 | 시간 363[s] | 손실 2.27
# | 에폭 1 |  반복 6761 / 9295 | 시간 364[s] | 손실 2.30
# | 에폭 1 |  반복 6781 / 9295 | 시간 365[s] | 손실 2.30
# | 에폭 1 |  반복 6801 / 9295 | 시간 366[s] | 손실 2.27
# | 에폭 1 |  반복 6821 / 9295 | 시간 367[s] | 손실 2.31
# | 에폭 1 |  반복 6841 / 9295 | 시간 368[s] | 손실 2.31
# | 에폭 1 |  반복 6861 / 9295 | 시간 369[s] | 손실 2.28
# | 에폭 1 |  반복 6881 / 9295 | 시간 370[s] | 손실 2.29
# | 에폭 1 |  반복 6901 / 9295 | 시간 371[s] | 손실 2.28
# | 에폭 1 |  반복 6921 / 9295 | 시간 372[s] | 손실 2.29
# | 에폭 1 |  반복 6941 / 9295 | 시간 373[s] | 손실 2.33
# | 에폭 1 |  반복 6961 / 9295 | 시간 375[s] | 손실 2.31
# | 에폭 1 |  반복 6981 / 9295 | 시간 376[s] | 손실 2.31
# | 에폭 1 |  반복 7001 / 9295 | 시간 377[s] | 손실 2.28
# | 에폭 1 |  반복 7021 / 9295 | 시간 378[s] | 손실 2.30
# | 에폭 1 |  반복 7041 / 9295 | 시간 379[s] | 손실 2.30
# | 에폭 1 |  반복 7061 / 9295 | 시간 380[s] | 손실 2.28
# | 에폭 1 |  반복 7081 / 9295 | 시간 381[s] | 손실 2.33
# | 에폭 1 |  반복 7101 / 9295 | 시간 382[s] | 손실 2.27
# | 에폭 1 |  반복 7121 / 9295 | 시간 383[s] | 손실 2.30
# | 에폭 1 |  반복 7141 / 9295 | 시간 384[s] | 손실 2.30
# | 에폭 1 |  반복 7161 / 9295 | 시간 385[s] | 손실 2.27
# | 에폭 1 |  반복 7181 / 9295 | 시간 386[s] | 손실 2.29
# | 에폭 1 |  반복 7201 / 9295 | 시간 387[s] | 손실 2.29
# | 에폭 1 |  반복 7221 / 9295 | 시간 388[s] | 손실 2.26
# | 에폭 1 |  반복 7241 / 9295 | 시간 389[s] | 손실 2.25
# | 에폭 1 |  반복 7261 / 9295 | 시간 391[s] | 손실 2.29
# | 에폭 1 |  반복 7281 / 9295 | 시간 392[s] | 손실 2.28
# | 에폭 1 |  반복 7301 / 9295 | 시간 393[s] | 손실 2.29
# | 에폭 1 |  반복 7321 / 9295 | 시간 394[s] | 손실 2.31
# | 에폭 1 |  반복 7341 / 9295 | 시간 395[s] | 손실 2.29
# | 에폭 1 |  반복 7361 / 9295 | 시간 396[s] | 손실 2.27
# | 에폭 1 |  반복 7381 / 9295 | 시간 397[s] | 손실 2.29
# | 에폭 1 |  반복 7401 / 9295 | 시간 398[s] | 손실 2.26
# | 에폭 1 |  반복 7421 / 9295 | 시간 399[s] | 손실 2.27
# | 에폭 1 |  반복 7441 / 9295 | 시간 400[s] | 손실 2.30
# | 에폭 1 |  반복 7461 / 9295 | 시간 401[s] | 손실 2.28
# | 에폭 1 |  반복 7481 / 9295 | 시간 402[s] | 손실 2.28
# | 에폭 1 |  반복 7501 / 9295 | 시간 403[s] | 손실 2.27
# | 에폭 1 |  반복 7521 / 9295 | 시간 404[s] | 손실 2.29
# | 에폭 1 |  반복 7541 / 9295 | 시간 405[s] | 손실 2.29
# | 에폭 1 |  반복 7561 / 9295 | 시간 407[s] | 손실 2.28
# | 에폭 1 |  반복 7581 / 9295 | 시간 408[s] | 손실 2.26
# | 에폭 1 |  반복 7601 / 9295 | 시간 409[s] | 손실 2.31
# | 에폭 1 |  반복 7621 / 9295 | 시간 410[s] | 손실 2.26
# | 에폭 1 |  반복 7641 / 9295 | 시간 411[s] | 손실 2.29
# | 에폭 1 |  반복 7661 / 9295 | 시간 412[s] | 손실 2.29
# | 에폭 1 |  반복 7681 / 9295 | 시간 413[s] | 손실 2.28
# | 에폭 1 |  반복 7701 / 9295 | 시간 414[s] | 손실 2.23
# | 에폭 1 |  반복 7721 / 9295 | 시간 415[s] | 손실 2.28
# | 에폭 1 |  반복 7741 / 9295 | 시간 416[s] | 손실 2.26
# | 에폭 1 |  반복 7761 / 9295 | 시간 417[s] | 손실 2.24
# | 에폭 1 |  반복 7781 / 9295 | 시간 418[s] | 손실 2.28
# | 에폭 1 |  반복 7801 / 9295 | 시간 419[s] | 손실 2.26
# | 에폭 1 |  반복 7821 / 9295 | 시간 420[s] | 손실 2.25
# | 에폭 1 |  반복 7841 / 9295 | 시간 421[s] | 손실 2.29
# | 에폭 1 |  반복 7861 / 9295 | 시간 423[s] | 손실 2.23
# | 에폭 1 |  반복 7881 / 9295 | 시간 424[s] | 손실 2.28
# | 에폭 1 |  반복 7901 / 9295 | 시간 425[s] | 손실 2.27
# | 에폭 1 |  반복 7921 / 9295 | 시간 426[s] | 손실 2.25
# | 에폭 1 |  반복 7941 / 9295 | 시간 427[s] | 손실 2.24
# | 에폭 1 |  반복 7961 / 9295 | 시간 428[s] | 손실 2.25
# | 에폭 1 |  반복 7981 / 9295 | 시간 429[s] | 손실 2.23
# | 에폭 1 |  반복 8001 / 9295 | 시간 430[s] | 손실 2.28
# | 에폭 1 |  반복 8021 / 9295 | 시간 431[s] | 손실 2.28
# | 에폭 1 |  반복 8041 / 9295 | 시간 432[s] | 손실 2.26
# | 에폭 1 |  반복 8061 / 9295 | 시간 433[s] | 손실 2.24
# | 에폭 1 |  반복 8081 / 9295 | 시간 434[s] | 손실 2.28
# | 에폭 1 |  반복 8101 / 9295 | 시간 435[s] | 손실 2.25
# | 에폭 1 |  반복 8121 / 9295 | 시간 436[s] | 손실 2.27
# | 에폭 1 |  반복 8141 / 9295 | 시간 437[s] | 손실 2.24
# | 에폭 1 |  반복 8161 / 9295 | 시간 439[s] | 손실 2.25
# | 에폭 1 |  반복 8181 / 9295 | 시간 440[s] | 손실 2.25
# | 에폭 1 |  반복 8201 / 9295 | 시간 441[s] | 손실 2.25
# | 에폭 1 |  반복 8221 / 9295 | 시간 442[s] | 손실 2.26
# | 에폭 1 |  반복 8241 / 9295 | 시간 443[s] | 손실 2.24
# | 에폭 1 |  반복 8261 / 9295 | 시간 444[s] | 손실 2.26
# | 에폭 1 |  반복 8281 / 9295 | 시간 445[s] | 손실 2.23
# | 에폭 1 |  반복 8301 / 9295 | 시간 446[s] | 손실 2.26
# | 에폭 1 |  반복 8321 / 9295 | 시간 447[s] | 손실 2.25
# | 에폭 1 |  반복 8341 / 9295 | 시간 448[s] | 손실 2.24
# | 에폭 1 |  반복 8361 / 9295 | 시간 449[s] | 손실 2.27
# | 에폭 1 |  반복 8381 / 9295 | 시간 450[s] | 손실 2.27
# | 에폭 1 |  반복 8401 / 9295 | 시간 451[s] | 손실 2.21
# | 에폭 1 |  반복 8421 / 9295 | 시간 452[s] | 손실 2.28
# | 에폭 1 |  반복 8441 / 9295 | 시간 453[s] | 손실 2.22
# | 에폭 1 |  반복 8461 / 9295 | 시간 455[s] | 손실 2.26
# | 에폭 1 |  반복 8481 / 9295 | 시간 456[s] | 손실 2.23
# | 에폭 1 |  반복 8501 / 9295 | 시간 457[s] | 손실 2.24
# | 에폭 1 |  반복 8521 / 9295 | 시간 458[s] | 손실 2.24
# | 에폭 1 |  반복 8541 / 9295 | 시간 459[s] | 손실 2.24
# | 에폭 1 |  반복 8561 / 9295 | 시간 460[s] | 손실 2.27
# | 에폭 1 |  반복 8581 / 9295 | 시간 461[s] | 손실 2.25
# | 에폭 1 |  반복 8601 / 9295 | 시간 462[s] | 손실 2.25
# | 에폭 1 |  반복 8621 / 9295 | 시간 463[s] | 손실 2.22
# | 에폭 1 |  반복 8641 / 9295 | 시간 464[s] | 손실 2.22
# | 에폭 1 |  반복 8661 / 9295 | 시간 465[s] | 손실 2.28
# | 에폭 1 |  반복 8681 / 9295 | 시간 466[s] | 손실 2.25
# | 에폭 1 |  반복 8701 / 9295 | 시간 467[s] | 손실 2.25
# | 에폭 1 |  반복 8721 / 9295 | 시간 468[s] | 손실 2.27
# | 에폭 1 |  반복 8741 / 9295 | 시간 469[s] | 손실 2.23
# | 에폭 1 |  반복 8761 / 9295 | 시간 471[s] | 손실 2.23
# | 에폭 1 |  반복 8781 / 9295 | 시간 472[s] | 손실 2.23
# | 에폭 1 |  반복 8801 / 9295 | 시간 473[s] | 손실 2.24
# | 에폭 1 |  반복 8821 / 9295 | 시간 474[s] | 손실 2.22
# | 에폭 1 |  반복 8841 / 9295 | 시간 475[s] | 손실 2.21
# | 에폭 1 |  반복 8861 / 9295 | 시간 476[s] | 손실 2.20
# | 에폭 1 |  반복 8881 / 9295 | 시간 477[s] | 손실 2.25
# | 에폭 1 |  반복 8901 / 9295 | 시간 478[s] | 손실 2.23
# | 에폭 1 |  반복 8921 / 9295 | 시간 479[s] | 손실 2.25
# | 에폭 1 |  반복 8941 / 9295 | 시간 481[s] | 손실 2.22
# | 에폭 1 |  반복 8961 / 9295 | 시간 482[s] | 손실 2.21
# | 에폭 1 |  반복 8981 / 9295 | 시간 483[s] | 손실 2.22
# | 에폭 1 |  반복 9001 / 9295 | 시간 484[s] | 손실 2.24
# | 에폭 1 |  반복 9021 / 9295 | 시간 485[s] | 손실 2.23
# | 에폭 1 |  반복 9041 / 9295 | 시간 486[s] | 손실 2.22
# | 에폭 1 |  반복 9061 / 9295 | 시간 488[s] | 손실 2.28
# | 에폭 1 |  반복 9081 / 9295 | 시간 489[s] | 손실 2.23
# | 에폭 1 |  반복 9101 / 9295 | 시간 490[s] | 손실 2.22
# | 에폭 1 |  반복 9121 / 9295 | 시간 491[s] | 손실 2.24
# | 에폭 1 |  반복 9141 / 9295 | 시간 492[s] | 손실 2.24
# | 에폭 1 |  반복 9161 / 9295 | 시간 493[s] | 손실 2.24
# | 에폭 1 |  반복 9181 / 9295 | 시간 495[s] | 손실 2.21
# | 에폭 1 |  반복 9201 / 9295 | 시간 496[s] | 손실 2.22
# | 에폭 1 |  반복 9221 / 9295 | 시간 497[s] | 손실 2.23
# | 에폭 1 |  반복 9241 / 9295 | 시간 498[s] | 손실 2.23
# | 에폭 1 |  반복 9261 / 9295 | 시간 499[s] | 손실 2.22
# | 에폭 1 |  반복 9281 / 9295 | 시간 500[s] | 손실 2.20
# | 에폭 2 |  반복 1 / 9295 | 시간 501[s] | 손실 2.20
# | 에폭 2 |  반복 21 / 9295 | 시간 502[s] | 손실 2.21
# | 에폭 2 |  반복 41 / 9295 | 시간 503[s] | 손실 2.15
# | 에폭 2 |  반복 61 / 9295 | 시간 505[s] | 손실 2.18
# | 에폭 2 |  반복 81 / 9295 | 시간 506[s] | 손실 2.17
# | 에폭 2 |  반복 101 / 9295 | 시간 507[s] | 손실 2.21
# | 에폭 2 |  반복 121 / 9295 | 시간 508[s] | 손실 2.16
# | 에폭 2 |  반복 141 / 9295 | 시간 509[s] | 손실 2.16
# | 에폭 2 |  반복 161 / 9295 | 시간 510[s] | 손실 2.18
# | 에폭 2 |  반복 181 / 9295 | 시간 511[s] | 손실 2.20
# | 에폭 2 |  반복 201 / 9295 | 시간 512[s] | 손실 2.19
# | 에폭 2 |  반복 221 / 9295 | 시간 513[s] | 손실 2.14
# | 에폭 2 |  반복 241 / 9295 | 시간 514[s] | 손실 2.19
# | 에폭 2 |  반복 261 / 9295 | 시간 516[s] | 손실 2.17
# | 에폭 2 |  반복 281 / 9295 | 시간 517[s] | 손실 2.19
# | 에폭 2 |  반복 301 / 9295 | 시간 518[s] | 손실 2.17
# | 에폭 2 |  반복 321 / 9295 | 시간 519[s] | 손실 2.17
# | 에폭 2 |  반복 341 / 9295 | 시간 520[s] | 손실 2.17
# | 에폭 2 |  반복 361 / 9295 | 시간 521[s] | 손실 2.17
# | 에폭 2 |  반복 381 / 9295 | 시간 522[s] | 손실 2.19
# | 에폭 2 |  반복 401 / 9295 | 시간 523[s] | 손실 2.18
# | 에폭 2 |  반복 421 / 9295 | 시간 524[s] | 손실 2.20
# | 에폭 2 |  반복 441 / 9295 | 시간 525[s] | 손실 2.17
# | 에폭 2 |  반복 461 / 9295 | 시간 526[s] | 손실 2.15
# | 에폭 2 |  반복 481 / 9295 | 시간 528[s] | 손실 2.17
# | 에폭 2 |  반복 501 / 9295 | 시간 529[s] | 손실 2.18
# | 에폭 2 |  반복 521 / 9295 | 시간 530[s] | 손실 2.18
# | 에폭 2 |  반복 541 / 9295 | 시간 531[s] | 손실 2.14
# | 에폭 2 |  반복 561 / 9295 | 시간 532[s] | 손실 2.15
# | 에폭 2 |  반복 581 / 9295 | 시간 533[s] | 손실 2.13
# | 에폭 2 |  반복 601 / 9295 | 시간 534[s] | 손실 2.15
# | 에폭 2 |  반복 621 / 9295 | 시간 535[s] | 손실 2.16
# | 에폭 2 |  반복 641 / 9295 | 시간 536[s] | 손실 2.16
# | 에폭 2 |  반복 661 / 9295 | 시간 537[s] | 손실 2.22
# | 에폭 2 |  반복 681 / 9295 | 시간 538[s] | 손실 2.16
# | 에폭 2 |  반복 701 / 9295 | 시간 540[s] | 손실 2.16
# | 에폭 2 |  반복 721 / 9295 | 시간 541[s] | 손실 2.17
# | 에폭 2 |  반복 741 / 9295 | 시간 542[s] | 손실 2.17
# | 에폭 2 |  반복 761 / 9295 | 시간 543[s] | 손실 2.19
# | 에폭 2 |  반복 781 / 9295 | 시간 544[s] | 손실 2.19
# | 에폭 2 |  반복 801 / 9295 | 시간 545[s] | 손실 2.16
# | 에폭 2 |  반복 821 / 9295 | 시간 546[s] | 손실 2.15
# | 에폭 2 |  반복 841 / 9295 | 시간 547[s] | 손실 2.19
# | 에폭 2 |  반복 861 / 9295 | 시간 548[s] | 손실 2.19
# | 에폭 2 |  반복 881 / 9295 | 시간 549[s] | 손실 2.19
# | 에폭 2 |  반복 901 / 9295 | 시간 550[s] | 손실 2.20
# | 에폭 2 |  반복 921 / 9295 | 시간 551[s] | 손실 2.19
# | 에폭 2 |  반복 941 / 9295 | 시간 553[s] | 손실 2.20
# | 에폭 2 |  반복 961 / 9295 | 시간 554[s] | 손실 2.15
# | 에폭 2 |  반복 981 / 9295 | 시간 555[s] | 손실 2.17
# | 에폭 2 |  반복 1001 / 9295 | 시간 556[s] | 손실 2.15
# | 에폭 2 |  반복 1021 / 9295 | 시간 557[s] | 손실 2.17
# | 에폭 2 |  반복 1041 / 9295 | 시간 558[s] | 손실 2.16
# | 에폭 2 |  반복 1061 / 9295 | 시간 559[s] | 손실 2.15
# | 에폭 2 |  반복 1081 / 9295 | 시간 560[s] | 손실 2.16
# | 에폭 2 |  반복 1101 / 9295 | 시간 561[s] | 손실 2.15
# | 에폭 2 |  반복 1121 / 9295 | 시간 562[s] | 손실 2.16
# | 에폭 2 |  반복 1141 / 9295 | 시간 563[s] | 손실 2.19
# | 에폭 2 |  반복 1161 / 9295 | 시간 564[s] | 손실 2.15
# | 에폭 2 |  반복 1181 / 9295 | 시간 566[s] | 손실 2.18
# | 에폭 2 |  반복 1201 / 9295 | 시간 567[s] | 손실 2.14
# | 에폭 2 |  반복 1221 / 9295 | 시간 568[s] | 손실 2.15
# | 에폭 2 |  반복 1241 / 9295 | 시간 569[s] | 손실 2.13
# | 에폭 2 |  반복 1261 / 9295 | 시간 570[s] | 손실 2.17
# | 에폭 2 |  반복 1281 / 9295 | 시간 571[s] | 손실 2.15
# | 에폭 2 |  반복 1301 / 9295 | 시간 572[s] | 손실 2.12
# | 에폭 2 |  반복 1321 / 9295 | 시간 573[s] | 손실 2.16
# | 에폭 2 |  반복 1341 / 9295 | 시간 574[s] | 손실 2.14
# | 에폭 2 |  반복 1361 / 9295 | 시간 575[s] | 손실 2.16
# | 에폭 2 |  반복 1381 / 9295 | 시간 576[s] | 손실 2.13
# | 에폭 2 |  반복 1401 / 9295 | 시간 577[s] | 손실 2.18
# | 에폭 2 |  반복 1421 / 9295 | 시간 579[s] | 손실 2.16
# | 에폭 2 |  반복 1441 / 9295 | 시간 580[s] | 손실 2.17
# | 에폭 2 |  반복 1461 / 9295 | 시간 581[s] | 손실 2.14
# | 에폭 2 |  반복 1481 / 9295 | 시간 582[s] | 손실 2.14
# | 에폭 2 |  반복 1501 / 9295 | 시간 583[s] | 손실 2.13
# | 에폭 2 |  반복 1521 / 9295 | 시간 584[s] | 손실 2.13
# | 에폭 2 |  반복 1541 / 9295 | 시간 585[s] | 손실 2.15
# | 에폭 2 |  반복 1561 / 9295 | 시간 586[s] | 손실 2.13
# | 에폭 2 |  반복 1581 / 9295 | 시간 587[s] | 손실 2.17
# | 에폭 2 |  반복 1601 / 9295 | 시간 588[s] | 손실 2.14
# | 에폭 2 |  반복 1621 / 9295 | 시간 589[s] | 손실 2.16
# | 에폭 2 |  반복 1641 / 9295 | 시간 591[s] | 손실 2.13
# | 에폭 2 |  반복 1661 / 9295 | 시간 592[s] | 손실 2.16
# | 에폭 2 |  반복 1681 / 9295 | 시간 593[s] | 손실 2.14
# | 에폭 2 |  반복 1701 / 9295 | 시간 594[s] | 손실 2.12
# | 에폭 2 |  반복 1721 / 9295 | 시간 595[s] | 손실 2.16
# | 에폭 2 |  반복 1741 / 9295 | 시간 596[s] | 손실 2.16
# | 에폭 2 |  반복 1761 / 9295 | 시간 597[s] | 손실 2.15
# | 에폭 2 |  반복 1781 / 9295 | 시간 598[s] | 손실 2.15
# | 에폭 2 |  반복 1801 / 9295 | 시간 599[s] | 손실 2.14
# | 에폭 2 |  반복 1821 / 9295 | 시간 600[s] | 손실 2.16
# | 에폭 2 |  반복 1841 / 9295 | 시간 601[s] | 손실 2.12
# | 에폭 2 |  반복 1861 / 9295 | 시간 602[s] | 손실 2.16
# | 에폭 2 |  반복 1881 / 9295 | 시간 604[s] | 손실 2.16
# | 에폭 2 |  반복 1901 / 9295 | 시간 605[s] | 손실 2.13
# | 에폭 2 |  반복 1921 / 9295 | 시간 606[s] | 손실 2.12
# | 에폭 2 |  반복 1941 / 9295 | 시간 607[s] | 손실 2.14
# | 에폭 2 |  반복 1961 / 9295 | 시간 608[s] | 손실 2.17
# | 에폭 2 |  반복 1981 / 9295 | 시간 609[s] | 손실 2.14
# | 에폭 2 |  반복 2001 / 9295 | 시간 610[s] | 손실 2.14
# | 에폭 2 |  반복 2021 / 9295 | 시간 611[s] | 손실 2.13
# | 에폭 2 |  반복 2041 / 9295 | 시간 612[s] | 손실 2.15
# | 에폭 2 |  반복 2061 / 9295 | 시간 613[s] | 손실 2.13
# | 에폭 2 |  반복 2081 / 9295 | 시간 614[s] | 손실 2.16
# | 에폭 2 |  반복 2101 / 9295 | 시간 615[s] | 손실 2.13
# | 에폭 2 |  반복 2121 / 9295 | 시간 617[s] | 손실 2.11
# | 에폭 2 |  반복 2141 / 9295 | 시간 618[s] | 손실 2.14
# | 에폭 2 |  반복 2161 / 9295 | 시간 619[s] | 손실 2.13
# | 에폭 2 |  반복 2181 / 9295 | 시간 620[s] | 손실 2.14
# | 에폭 2 |  반복 2201 / 9295 | 시간 621[s] | 손실 2.13
# | 에폭 2 |  반복 2221 / 9295 | 시간 622[s] | 손실 2.12
# | 에폭 2 |  반복 2241 / 9295 | 시간 623[s] | 손실 2.12
# | 에폭 2 |  반복 2261 / 9295 | 시간 624[s] | 손실 2.13
# | 에폭 2 |  반복 2281 / 9295 | 시간 625[s] | 손실 2.14
# | 에폭 2 |  반복 2301 / 9295 | 시간 626[s] | 손실 2.15
# | 에폭 2 |  반복 2321 / 9295 | 시간 627[s] | 손실 2.12
# | 에폭 2 |  반복 2341 / 9295 | 시간 628[s] | 손실 2.14
# | 에폭 2 |  반복 2361 / 9295 | 시간 630[s] | 손실 2.18
# | 에폭 2 |  반복 2381 / 9295 | 시간 631[s] | 손실 2.14
# | 에폭 2 |  반복 2401 / 9295 | 시간 632[s] | 손실 2.12
# | 에폭 2 |  반복 2421 / 9295 | 시간 633[s] | 손실 2.13
# | 에폭 2 |  반복 2441 / 9295 | 시간 634[s] | 손실 2.14
# | 에폭 2 |  반복 2461 / 9295 | 시간 635[s] | 손실 2.13
# | 에폭 2 |  반복 2481 / 9295 | 시간 636[s] | 손실 2.11
# | 에폭 2 |  반복 2501 / 9295 | 시간 637[s] | 손실 2.09
# | 에폭 2 |  반복 2521 / 9295 | 시간 638[s] | 손실 2.13
# | 에폭 2 |  반복 2541 / 9295 | 시간 639[s] | 손실 2.16
# | 에폭 2 |  반복 2561 / 9295 | 시간 640[s] | 손실 2.15
# | 에폭 2 |  반복 2581 / 9295 | 시간 641[s] | 손실 2.15
# | 에폭 2 |  반복 2601 / 9295 | 시간 643[s] | 손실 2.12
# | 에폭 2 |  반복 2621 / 9295 | 시간 644[s] | 손실 2.13
# | 에폭 2 |  반복 2641 / 9295 | 시간 645[s] | 손실 2.13
# | 에폭 2 |  반복 2661 / 9295 | 시간 646[s] | 손실 2.12
# | 에폭 2 |  반복 2681 / 9295 | 시간 647[s] | 손실 2.09
# | 에폭 2 |  반복 2701 / 9295 | 시간 648[s] | 손실 2.14
# | 에폭 2 |  반복 2721 / 9295 | 시간 649[s] | 손실 2.15
# | 에폭 2 |  반복 2741 / 9295 | 시간 650[s] | 손실 2.11
# | 에폭 2 |  반복 2761 / 9295 | 시간 651[s] | 손실 2.13
# | 에폭 2 |  반복 2781 / 9295 | 시간 652[s] | 손실 2.15
# | 에폭 2 |  반복 2801 / 9295 | 시간 653[s] | 손실 2.12
# | 에폭 2 |  반복 2821 / 9295 | 시간 654[s] | 손실 2.17
# | 에폭 2 |  반복 2841 / 9295 | 시간 656[s] | 손실 2.12
# | 에폭 2 |  반복 2861 / 9295 | 시간 657[s] | 손실 2.15
# | 에폭 2 |  반복 2881 / 9295 | 시간 658[s] | 손실 2.11
# | 에폭 2 |  반복 2901 / 9295 | 시간 659[s] | 손실 2.15
# | 에폭 2 |  반복 2921 / 9295 | 시간 660[s] | 손실 2.13
# | 에폭 2 |  반복 2941 / 9295 | 시간 661[s] | 손실 2.13
# | 에폭 2 |  반복 2961 / 9295 | 시간 662[s] | 손실 2.11
# | 에폭 2 |  반복 2981 / 9295 | 시간 663[s] | 손실 2.10
# | 에폭 2 |  반복 3001 / 9295 | 시간 664[s] | 손실 2.15
# | 에폭 2 |  반복 3021 / 9295 | 시간 665[s] | 손실 2.13
# | 에폭 2 |  반복 3041 / 9295 | 시간 666[s] | 손실 2.12
# | 에폭 2 |  반복 3061 / 9295 | 시간 668[s] | 손실 2.11
# | 에폭 2 |  반복 3081 / 9295 | 시간 669[s] | 손실 2.15
# | 에폭 2 |  반복 3101 / 9295 | 시간 670[s] | 손실 2.11
# | 에폭 2 |  반복 3121 / 9295 | 시간 671[s] | 손실 2.13
# | 에폭 2 |  반복 3141 / 9295 | 시간 672[s] | 손실 2.10
# | 에폭 2 |  반복 3161 / 9295 | 시간 673[s] | 손실 2.14
# | 에폭 2 |  반복 3181 / 9295 | 시간 674[s] | 손실 2.13
# | 에폭 2 |  반복 3201 / 9295 | 시간 675[s] | 손실 2.11
# | 에폭 2 |  반복 3221 / 9295 | 시간 676[s] | 손실 2.11
# | 에폭 2 |  반복 3241 / 9295 | 시간 677[s] | 손실 2.11
# | 에폭 2 |  반복 3261 / 9295 | 시간 678[s] | 손실 2.11
# | 에폭 2 |  반복 3281 / 9295 | 시간 679[s] | 손실 2.10
# | 에폭 2 |  반복 3301 / 9295 | 시간 681[s] | 손실 2.14
# | 에폭 2 |  반복 3321 / 9295 | 시간 682[s] | 손실 2.15
# | 에폭 2 |  반복 3341 / 9295 | 시간 683[s] | 손실 2.14
# | 에폭 2 |  반복 3361 / 9295 | 시간 684[s] | 손실 2.13
# | 에폭 2 |  반복 3381 / 9295 | 시간 685[s] | 손실 2.13
# | 에폭 2 |  반복 3401 / 9295 | 시간 686[s] | 손실 2.13
# | 에폭 2 |  반복 3421 / 9295 | 시간 687[s] | 손실 2.08
# | 에폭 2 |  반복 3441 / 9295 | 시간 688[s] | 손실 2.08
# | 에폭 2 |  반복 3461 / 9295 | 시간 689[s] | 손실 2.11
# | 에폭 2 |  반복 3481 / 9295 | 시간 690[s] | 손실 2.10
# | 에폭 2 |  반복 3501 / 9295 | 시간 692[s] | 손실 2.14
# | 에폭 2 |  반복 3521 / 9295 | 시간 693[s] | 손실 2.12
# | 에폭 2 |  반복 3541 / 9295 | 시간 694[s] | 손실 2.08
# | 에폭 2 |  반복 3561 / 9295 | 시간 695[s] | 손실 2.12
# | 에폭 2 |  반복 3581 / 9295 | 시간 696[s] | 손실 2.12
# | 에폭 2 |  반복 3601 / 9295 | 시간 697[s] | 손실 2.12
# | 에폭 2 |  반복 3621 / 9295 | 시간 698[s] | 손실 2.12
# | 에폭 2 |  반복 3641 / 9295 | 시간 699[s] | 손실 2.13
# | 에폭 2 |  반복 3661 / 9295 | 시간 700[s] | 손실 2.12
# | 에폭 2 |  반복 3681 / 9295 | 시간 701[s] | 손실 2.10
# | 에폭 2 |  반복 3701 / 9295 | 시간 702[s] | 손실 2.13
# | 에폭 2 |  반복 3721 / 9295 | 시간 704[s] | 손실 2.14
# | 에폭 2 |  반복 3741 / 9295 | 시간 705[s] | 손실 2.11
# | 에폭 2 |  반복 3761 / 9295 | 시간 706[s] | 손실 2.15
# | 에폭 2 |  반복 3781 / 9295 | 시간 707[s] | 손실 2.08
# | 에폭 2 |  반복 3801 / 9295 | 시간 708[s] | 손실 2.10
# | 에폭 2 |  반복 3821 / 9295 | 시간 709[s] | 손실 2.13
# | 에폭 2 |  반복 3841 / 9295 | 시간 710[s] | 손실 2.12
# | 에폭 2 |  반복 3861 / 9295 | 시간 711[s] | 손실 2.12
# | 에폭 2 |  반복 3881 / 9295 | 시간 712[s] | 손실 2.11
# | 에폭 2 |  반복 3901 / 9295 | 시간 713[s] | 손실 2.12
# | 에폭 2 |  반복 3921 / 9295 | 시간 715[s] | 손실 2.10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# f:\Deep_Learning_From_Scratch2\20230922 - 4장_word2vec 속도 개선.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=25'>26</a> trainer = Trainer(model, optimizer)
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=27'>28</a> # 학습 시작
# ---> <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=28'>29</a> trainer.fit(contexts, target, max_epoch, batch_size)
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=29'>30</a> trainer.plot()
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=31'>32</a> # 나중에 사용할 수 있도록 필요한 데이터 저장
#
# File f:\Deep_Learning_From_Scratch2\common\trainer.py:39, in Trainer.fit(self, x, t, max_epoch, batch_size, max_grad, eval_interval)
#      36 batch_t = t[iters*batch_size:(iters+1)*batch_size]
#      38 # 기울기 구해 매개변수 갱신
# ---> 39 loss = model.forward(batch_x, batch_t)
#      40 model.backward()
#      41 params, grads = remove_duplicate(model.params, model.grads)  # 공유된 가중치를 하나로 모음
#
# f:\Deep_Learning_From_Scratch2\20230922 - 4장_word2vec 속도 개선.ipynb Cell 10 line 3
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=33'>34</a>     h += layer.forward(contexts[:, i])
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=34'>35</a> h *= 1 / len(self.in_layers)
# ---> <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=35'>36</a> loss = self.ns_loss.forward(h, target)
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=36'>37</a> return loss
#
# f:\Deep_Learning_From_Scratch2\20230922 - 4장_word2vec 속도 개선.ipynb Cell 10 line 8
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=85'>86</a> def forward(self, h, target):
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=86'>87</a>     batch_size = target.shape[0]
# ---> <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=87'>88</a>     negative_sample = self.sampler.get_negative_sample(target)
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=89'>90</a>     # 긍정적 예 순전파
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=90'>91</a>     score = self.embed_dot_layers[0].forward(h, target)
#
# f:\Deep_Learning_From_Scratch2\20230922 - 4장_word2vec 속도 개선.ipynb Cell 10 line 6
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=56'>57</a> negative_sample = np.zeros((batch_size, self.sample_size), dtype=np.int32)
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=58'>59</a> for i in range(batch_size):
# ---> <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=59'>60</a>     p = self.word_p.copy()
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=60'>61</a>     target_idx = target[i]
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20230922%20-%204%EC%9E%A5_word2vec%20%EC%86%8D%EB%8F%84%20%EA%B0%9C%EC%84%A0.ipynb#X15sZmlsZQ%3D%3D?line=61'>62</a>     p[target_idx] = 0
#
# KeyboardInterrupt:

# %% [markdown]
# ## CBOW 모델 평가

# %%
import sys
sys.path.append('..')
from common.util import most_similar
import pickle

pkl_file = 'cbow_params.pkl'

with open(pkl_file, 'rb') as f:
    params = pickle.load(f)
    word_vecs = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']

querys = ['you', 'year', 'car', 'toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)
