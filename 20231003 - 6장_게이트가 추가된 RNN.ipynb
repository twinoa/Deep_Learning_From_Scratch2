# %% [markdown]
# ## 기본 RNN의 단점
# 계층이 많아질 수록 예전 데이터의 기울기 값이 극단적으로 작거나 커서 예전의 데이터를 제대로 학습을 못함

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 2   # 미니배치 크기
H = 3   # 은닉 상태 벡터의 차원 수
T = 20  # 시계열 데이터의 길이

dh = np.ones((N, H))
np.random.seed(3)  # 재현할 수 있도록 난수의 시드 고정
Wh = np.random.randn(H, H)

norm_list = []
for t in range(T):
    dh = np.matmul(dh, Wh.T)
    norm = np.sqrt(np.sum(dh**2)) / N
    norm_list.append(norm)

# %% [markdown]
# ## 기울기 폭발 대책
# 기울기 클리핑 기법 사용, threshold보다 기울기가 크면 수정

# %%
import numpy as np

dW1 = np.random.rand(3, 3) * 10
dW2 = np.random.rand(3, 3) * 10
grads = [dW1, dW2]
max_norm = 5.0

def clip_grads(grads, max_norm):
    total_norm = 0
    for grad in grads:
        total_norm += np.sum(grad ** 2)
    total_norm = np.sqrt(total_norm)

    rate = max_norm / (total_norm + 1e-6)
    if rate < 1:
        for grad in grads:
            grad *= rate

# %% [markdown]
# ## LSTM 구현

# %%
class LSTM:
    def __init__(self, Wx, Wh, b):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None

    def forward(self, x, h_prev, c_prev):
        Wx, Wh, b = self.params
        N, H = h_prev.shape

        A = np.matmul(x, Wx) + np.matmul(h_prev, Wh) + b

        # slice
        f = A[:, :H]
        g = A[:, H:2*H]
        i = A[:, 2*H:3*H]
        o = A[:, 3*H:]

        f = sigmoid(f)
        g = np.tang(g)
        i = sigmoid(i)
        o = sigmoid(o)

        c_next = f * c_prev + g * i
        h_next = o * np.tanh(c_next)

        self.cache = (x, h_prev, c_prev, i, f, g, o, c_next)
        return h_next, c_next

# %% [markdown]
# ## Time LSTM 구현

# %%
class TimeLSTM:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None
        self.h, self.c = None, None
        self.dh = None
        self.stateful = stateful

    def forward(self, xs):
        Wx, Wh, b = self.params
        N, T, D = xs.shape
        H = Wh.shape[0]

        self.layers = []
        hs = np.empty((N, T, H), dtype='f')

        if not self.stateful or self.h is None:
            self.h = np.zeros((N, H), dtype='f')
        if not self.stateful or self.c is None:
            self.c = np.zeros((N, H), dtype='f')

        for t in range(T):
            layer = LSTM(*self.params)
            self.h, self.c = layer.forward(xs[:, t, :], self.h, self.c)
            hs[:, t, :] = self.h

            self.layers.append(layer)

        return hs
    
    def backward(self, dhs):
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D = Wx.shape[0]

        dxs = np.empty((N, T, D), dtype='f')
        dh, dc = 0, 0

        grads = [0, 0, 0]
        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh, dc = layer.backward(dhs[:, t, :] + dh, dc)
            dxs[:, t, :] = dx
            for i, grad in enumerate(layer.grads):
                grads[i] += grad

        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
            self.dh = dh
            return dxs
        
        def sef_state(self, h, c=None):
            self.h, self.c = h, c

        def reset_state(self):
            self.h, self.c = None, None

# %% [markdown]
# ## LSTM을 사용한 언어 모델

# %%
import sys
sys.path.append('..')
from common.time_layers import *
import pickle

class Rnnlm:
    def __init__(self, vocab_size=10000, wordvec_size=100, hidden_size=100):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        # 가중치 초기화
        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        # 계층 생성
        self.layers = [
            TimeEmbedding(embed_W),
            TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True),
            TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layer = self.layers[1]

        # 모든 가중치와 기울기를 리스트에 모은다.
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

        def predict(self, xs):
            for layer in self.layers:
                xs = layer.forward(xs)
            return xs

        def forward(self, xs, ts):
            score = self.predict(xs)
            loss = self.loss_layer.forward(score, ts)
            return loss
        
        def backward(self, dout=1):
            dout = self.loss_layer.backward(dout)
            for layer in reversed(self.layers):
                dout = layer.backward(dout)
            return dout
        
        def reset_state(self):
            self.lstm_layer.reset_state()

        def save_parmas(self, file_name='Rnnlm.pkl'):
            with open(file_name, 'wb') as f:
                pickle.dump(self.params, f)

        def load_params(self, file_name='Rnnlm.pkl'):
            with open(file_name, 'rb') as f:
                self.params = pickle.load(f)

# %%
import sys
sys.path.append('..')
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
from rnnlm import Rnnlm

# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 100
hidden_size = 100  # RNN의 은닉 상태 벡터의 원소 수
time_size = 35     # RNN을 펼치는 크기
lr = 20.0
max_epoch = 4
max_grad = 0.25

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# 모델 생성
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

# 기울기 클리핑을 적용하여 학습
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad, eval_interval=20)
trainer.plot(ylim=(0, 500))

# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)

# 매게변수 저장
model.save_params()
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 10000.46
# | 에폭 1 |  반복 21 / 1327 | 시간 4[s] | 퍼플렉서티 2942.00
# | 에폭 1 |  반복 41 / 1327 | 시간 8[s] | 퍼플렉서티 1212.65
# | 에폭 1 |  반복 61 / 1327 | 시간 11[s] | 퍼플렉서티 942.89
# | 에폭 1 |  반복 81 / 1327 | 시간 15[s] | 퍼플렉서티 796.53
# | 에폭 1 |  반복 101 / 1327 | 시간 19[s] | 퍼플렉서티 655.98
# | 에폭 1 |  반복 121 / 1327 | 시간 22[s] | 퍼플렉서티 639.34
# | 에폭 1 |  반복 141 / 1327 | 시간 26[s] | 퍼플렉서티 593.22
# | 에폭 1 |  반복 161 / 1327 | 시간 30[s] | 퍼플렉서티 567.29
# | 에폭 1 |  반복 181 / 1327 | 시간 33[s] | 퍼플렉서티 559.06
# | 에폭 1 |  반복 201 / 1327 | 시간 37[s] | 퍼플렉서티 503.33
# | 에폭 1 |  반복 221 / 1327 | 시간 41[s] | 퍼플렉서티 490.31
# | 에폭 1 |  반복 241 / 1327 | 시간 44[s] | 퍼플렉서티 431.21
# | 에폭 1 |  반복 261 / 1327 | 시간 48[s] | 퍼플렉서티 456.23
# | 에폭 1 |  반복 281 / 1327 | 시간 52[s] | 퍼플렉서티 444.63
# | 에폭 1 |  반복 301 / 1327 | 시간 55[s] | 퍼플렉서티 386.53
# | 에폭 1 |  반복 321 / 1327 | 시간 59[s] | 퍼플렉서티 344.69
# | 에폭 1 |  반복 341 / 1327 | 시간 63[s] | 퍼플렉서티 396.61
# | 에폭 1 |  반복 361 / 1327 | 시간 66[s] | 퍼플렉서티 405.61
# | 에폭 1 |  반복 381 / 1327 | 시간 70[s] | 퍼플렉서티 332.02
# | 에폭 1 |  반복 401 / 1327 | 시간 74[s] | 퍼플렉서티 349.00
# | 에폭 1 |  반복 421 / 1327 | 시간 78[s] | 퍼플렉서티 345.44
# | 에폭 1 |  반복 441 / 1327 | 시간 81[s] | 퍼플렉서티 330.58
# | 에폭 1 |  반복 461 / 1327 | 시간 85[s] | 퍼플렉서티 324.10
# | 에폭 1 |  반복 481 / 1327 | 시간 88[s] | 퍼플렉서티 302.72
# | 에폭 1 |  반복 501 / 1327 | 시간 92[s] | 퍼플렉서티 315.30
# | 에폭 1 |  반복 521 / 1327 | 시간 96[s] | 퍼플렉서티 298.99
# | 에폭 1 |  반복 541 / 1327 | 시간 99[s] | 퍼플렉서티 318.81
# | 에폭 1 |  반복 561 / 1327 | 시간 103[s] | 퍼플렉서티 283.07
# | 에폭 1 |  반복 581 / 1327 | 시간 107[s] | 퍼플렉서티 259.42
# | 에폭 1 |  반복 601 / 1327 | 시간 111[s] | 퍼플렉서티 335.28
# | 에폭 1 |  반복 621 / 1327 | 시간 114[s] | 퍼플렉서티 309.75
# | 에폭 1 |  반복 641 / 1327 | 시간 118[s] | 퍼플렉서티 277.38
# | 에폭 1 |  반복 661 / 1327 | 시간 121[s] | 퍼플렉서티 267.95
# | 에폭 1 |  반복 681 / 1327 | 시간 125[s] | 퍼플렉서티 225.00
# | 에폭 1 |  반복 701 / 1327 | 시간 129[s] | 퍼플렉서티 249.73
# | 에폭 1 |  반복 721 / 1327 | 시간 133[s] | 퍼플렉서티 258.33
# | 에폭 1 |  반복 741 / 1327 | 시간 137[s] | 퍼플렉서티 222.43
# | 에폭 1 |  반복 761 / 1327 | 시간 140[s] | 퍼플렉서티 233.02
# | 에폭 1 |  반복 781 / 1327 | 시간 144[s] | 퍼플렉서티 216.33
# | 에폭 1 |  반복 801 / 1327 | 시간 148[s] | 퍼플렉서티 241.73
# | 에폭 1 |  반복 821 / 1327 | 시간 152[s] | 퍼플렉서티 222.83
# | 에폭 1 |  반복 841 / 1327 | 시간 155[s] | 퍼플렉서티 228.08
# | 에폭 1 |  반복 861 / 1327 | 시간 159[s] | 퍼플렉서티 219.48
# | 에폭 1 |  반복 881 / 1327 | 시간 163[s] | 퍼플렉서티 204.60
# | 에폭 1 |  반복 901 / 1327 | 시간 167[s] | 퍼플렉서티 252.26
# | 에폭 1 |  반복 921 / 1327 | 시간 170[s] | 퍼플렉서티 225.42
# | 에폭 1 |  반복 941 / 1327 | 시간 174[s] | 퍼플렉서티 228.83
# | 에폭 1 |  반복 961 / 1327 | 시간 178[s] | 퍼플렉서티 243.93
# | 에폭 1 |  반복 981 / 1327 | 시간 181[s] | 퍼플렉서티 228.73
# | 에폭 1 |  반복 1001 / 1327 | 시간 185[s] | 퍼플렉서티 192.09
# | 에폭 1 |  반복 1021 / 1327 | 시간 189[s] | 퍼플렉서티 225.90
# | 에폭 1 |  반복 1041 / 1327 | 시간 192[s] | 퍼플렉서티 207.61
# | 에폭 1 |  반복 1061 / 1327 | 시간 196[s] | 퍼플렉서티 195.99
# | 에폭 1 |  반복 1081 / 1327 | 시간 199[s] | 퍼플렉서티 168.80
# | 에폭 1 |  반복 1101 / 1327 | 시간 203[s] | 퍼플렉서티 193.95
# | 에폭 1 |  반복 1121 / 1327 | 시간 207[s] | 퍼플렉서티 229.86
# | 에폭 1 |  반복 1141 / 1327 | 시간 210[s] | 퍼플렉서티 208.55
# | 에폭 1 |  반복 1161 / 1327 | 시간 214[s] | 퍼플렉서티 196.92
# | 에폭 1 |  반복 1181 / 1327 | 시간 218[s] | 퍼플렉서티 189.03
# | 에폭 1 |  반복 1201 / 1327 | 시간 221[s] | 퍼플렉서티 163.17
# | 에폭 1 |  반복 1221 / 1327 | 시간 225[s] | 퍼플렉서티 159.72
# | 에폭 1 |  반복 1241 / 1327 | 시간 229[s] | 퍼플렉서티 189.54
# | 에폭 1 |  반복 1261 / 1327 | 시간 233[s] | 퍼플렉서티 170.79
# | 에폭 1 |  반복 1281 / 1327 | 시간 236[s] | 퍼플렉서티 180.38
# | 에폭 1 |  반복 1301 / 1327 | 시간 240[s] | 퍼플렉서티 220.23
# | 에폭 1 |  반복 1321 / 1327 | 시간 243[s] | 퍼플렉서티 209.65
# | 에폭 2 |  반복 1 / 1327 | 시간 245[s] | 퍼플렉서티 223.74
# | 에폭 2 |  반복 21 / 1327 | 시간 248[s] | 퍼플렉서티 202.68
# | 에폭 2 |  반복 41 / 1327 | 시간 252[s] | 퍼플렉서티 189.28
# | 에폭 2 |  반복 61 / 1327 | 시간 256[s] | 퍼플렉서티 176.01
# | 에폭 2 |  반복 81 / 1327 | 시간 259[s] | 퍼플렉서티 158.27
# | 에폭 2 |  반복 101 / 1327 | 시간 263[s] | 퍼플렉서티 154.29
# | 에폭 2 |  반복 121 / 1327 | 시간 267[s] | 퍼플렉서티 160.56
# | 에폭 2 |  반복 141 / 1327 | 시간 270[s] | 퍼플렉서티 177.46
# | 에폭 2 |  반복 161 / 1327 | 시간 274[s] | 퍼플렉서티 192.01
# | 에폭 2 |  반복 181 / 1327 | 시간 278[s] | 퍼플렉서티 199.25
# | 에폭 2 |  반복 201 / 1327 | 시간 281[s] | 퍼플렉서티 185.11
# | 에폭 2 |  반복 221 / 1327 | 시간 285[s] | 퍼플렉서티 183.97
# | 에폭 2 |  반복 241 / 1327 | 시간 289[s] | 퍼플렉서티 175.72
# | 에폭 2 |  반복 261 / 1327 | 시간 292[s] | 퍼플렉서티 185.38
# | 에폭 2 |  반복 281 / 1327 | 시간 296[s] | 퍼플렉서티 186.29
# | 에폭 2 |  반복 301 / 1327 | 시간 300[s] | 퍼플렉서티 166.97
# | 에폭 2 |  반복 321 / 1327 | 시간 303[s] | 퍼플렉서티 138.04
# | 에폭 2 |  반복 341 / 1327 | 시간 307[s] | 퍼플렉서티 173.89
# | 에폭 2 |  반복 361 / 1327 | 시간 311[s] | 퍼플렉서티 194.31
# | 에폭 2 |  반복 381 / 1327 | 시간 314[s] | 퍼플렉서티 152.21
# | 에폭 2 |  반복 401 / 1327 | 시간 318[s] | 퍼플렉서티 167.97
# | 에폭 2 |  반복 421 / 1327 | 시간 322[s] | 퍼플렉서티 156.28
# | 에폭 2 |  반복 441 / 1327 | 시간 325[s] | 퍼플렉서티 163.75
# | 에폭 2 |  반복 461 / 1327 | 시간 329[s] | 퍼플렉서티 156.96
# | 에폭 2 |  반복 481 / 1327 | 시간 333[s] | 퍼플렉서티 156.41
# | 에폭 2 |  반복 501 / 1327 | 시간 336[s] | 퍼플렉서티 170.37
# | 에폭 2 |  반복 521 / 1327 | 시간 340[s] | 퍼플렉서티 172.99
# | 에폭 2 |  반복 541 / 1327 | 시간 344[s] | 퍼플렉서티 175.45
# | 에폭 2 |  반복 561 / 1327 | 시간 347[s] | 퍼플렉서티 156.78
# | 에폭 2 |  반복 581 / 1327 | 시간 351[s] | 퍼플렉서티 139.62
# | 에폭 2 |  반복 601 / 1327 | 시간 355[s] | 퍼플렉서티 188.74
# | 에폭 2 |  반복 621 / 1327 | 시간 358[s] | 퍼플렉서티 181.65
# | 에폭 2 |  반복 641 / 1327 | 시간 362[s] | 퍼플렉서티 166.04
# | 에폭 2 |  반복 661 / 1327 | 시간 366[s] | 퍼플렉서티 154.76
# | 에폭 2 |  반복 681 / 1327 | 시간 369[s] | 퍼플렉서티 129.17
# | 에폭 2 |  반복 701 / 1327 | 시간 373[s] | 퍼플렉서티 151.26
# | 에폭 2 |  반복 721 / 1327 | 시간 377[s] | 퍼플렉서티 160.01
# | 에폭 2 |  반복 741 / 1327 | 시간 380[s] | 퍼플렉서티 134.60
# | 에폭 2 |  반복 761 / 1327 | 시간 384[s] | 퍼플렉서티 133.35
# | 에폭 2 |  반복 781 / 1327 | 시간 388[s] | 퍼플렉서티 135.36
# | 에폭 2 |  반복 801 / 1327 | 시간 391[s] | 퍼플렉서티 145.07
# | 에폭 2 |  반복 821 / 1327 | 시간 395[s] | 퍼플렉서티 142.90
# | 에폭 2 |  반복 841 / 1327 | 시간 399[s] | 퍼플렉서티 144.63
# | 에폭 2 |  반복 861 / 1327 | 시간 403[s] | 퍼플렉서티 145.47
# | 에폭 2 |  반복 881 / 1327 | 시간 406[s] | 퍼플렉서티 130.57
# | 에폭 2 |  반복 901 / 1327 | 시간 410[s] | 퍼플렉서티 166.78
# | 에폭 2 |  반복 921 / 1327 | 시간 414[s] | 퍼플렉서티 145.96
# | 에폭 2 |  반복 941 / 1327 | 시간 417[s] | 퍼플렉서티 152.84
# | 에폭 2 |  반복 961 / 1327 | 시간 421[s] | 퍼플렉서티 162.77
# | 에폭 2 |  반복 981 / 1327 | 시간 425[s] | 퍼플렉서티 154.08
# | 에폭 2 |  반복 1001 / 1327 | 시간 428[s] | 퍼플렉서티 131.74
# | 에폭 2 |  반복 1021 / 1327 | 시간 432[s] | 퍼플렉서티 157.21
# | 에폭 2 |  반복 1041 / 1327 | 시간 436[s] | 퍼플렉서티 144.39
# | 에폭 2 |  반복 1061 / 1327 | 시간 439[s] | 퍼플렉서티 129.47
# | 에폭 2 |  반복 1081 / 1327 | 시간 443[s] | 퍼플렉서티 110.01
# | 에폭 2 |  반복 1101 / 1327 | 시간 447[s] | 퍼플렉서티 120.60
# | 에폭 2 |  반복 1121 / 1327 | 시간 450[s] | 퍼플렉서티 154.91
# | 에폭 2 |  반복 1141 / 1327 | 시간 454[s] | 퍼플렉서티 143.10
# | 에폭 2 |  반복 1161 / 1327 | 시간 458[s] | 퍼플렉서티 133.62
# | 에폭 2 |  반복 1181 / 1327 | 시간 461[s] | 퍼플렉서티 134.75
# | 에폭 2 |  반복 1201 / 1327 | 시간 465[s] | 퍼플렉서티 112.34
# | 에폭 2 |  반복 1221 / 1327 | 시간 469[s] | 퍼플렉서티 109.29
# | 에폭 2 |  반복 1241 / 1327 | 시간 472[s] | 퍼플렉서티 131.29
# | 에폭 2 |  반복 1261 / 1327 | 시간 476[s] | 퍼플렉서티 123.59
# | 에폭 2 |  반복 1281 / 1327 | 시간 480[s] | 퍼플렉서티 123.88
# | 에폭 2 |  반복 1301 / 1327 | 시간 483[s] | 퍼플렉서티 155.58
# | 에폭 2 |  반복 1321 / 1327 | 시간 487[s] | 퍼플렉서티 152.20
# | 에폭 3 |  반복 1 / 1327 | 시간 488[s] | 퍼플렉서티 161.38
# | 에폭 3 |  반복 21 / 1327 | 시간 492[s] | 퍼플렉서티 143.23
# | 에폭 3 |  반복 41 / 1327 | 시간 496[s] | 퍼플렉서티 135.10
# | 에폭 3 |  반복 61 / 1327 | 시간 499[s] | 퍼플렉서티 128.56
# | 에폭 3 |  반복 81 / 1327 | 시간 503[s] | 퍼플렉서티 115.72
# | 에폭 3 |  반복 101 / 1327 | 시간 507[s] | 퍼플렉서티 105.01
# | 에폭 3 |  반복 121 / 1327 | 시간 510[s] | 퍼플렉서티 115.11
# | 에폭 3 |  반복 141 / 1327 | 시간 514[s] | 퍼플렉서티 126.20
# | 에폭 3 |  반복 161 / 1327 | 시간 518[s] | 퍼플렉서티 141.84
# | 에폭 3 |  반복 181 / 1327 | 시간 521[s] | 퍼플렉서티 150.71
# | 에폭 3 |  반복 201 / 1327 | 시간 525[s] | 퍼플렉서티 139.51
# | 에폭 3 |  반복 221 / 1327 | 시간 529[s] | 퍼플렉서티 141.48
# | 에폭 3 |  반복 241 / 1327 | 시간 532[s] | 퍼플렉서티 133.87
# | 에폭 3 |  반복 261 / 1327 | 시간 536[s] | 퍼플렉서티 139.54
# | 에폭 3 |  반복 281 / 1327 | 시간 539[s] | 퍼플렉서티 142.75
# | 에폭 3 |  반복 301 / 1327 | 시간 543[s] | 퍼플렉서티 124.15
# | 에폭 3 |  반복 321 / 1327 | 시간 547[s] | 퍼플렉서티 101.51
# | 에폭 3 |  반복 341 / 1327 | 시간 550[s] | 퍼플렉서티 124.72
# | 에폭 3 |  반복 361 / 1327 | 시간 554[s] | 퍼플렉서티 150.06
# | 에폭 3 |  반복 381 / 1327 | 시간 558[s] | 퍼플렉서티 114.16
# | 에폭 3 |  반복 401 / 1327 | 시간 561[s] | 퍼플렉서티 130.03
# | 에폭 3 |  반복 421 / 1327 | 시간 565[s] | 퍼플렉서티 113.29
# | 에폭 3 |  반복 441 / 1327 | 시간 569[s] | 퍼플렉서티 123.02
# | 에폭 3 |  반복 461 / 1327 | 시간 572[s] | 퍼플렉서티 118.18
# | 에폭 3 |  반복 481 / 1327 | 시간 576[s] | 퍼플렉서티 119.61
# | 에폭 3 |  반복 501 / 1327 | 시간 580[s] | 퍼플렉서티 129.54
# | 에폭 3 |  반복 521 / 1327 | 시간 583[s] | 퍼플렉서티 138.42
# | 에폭 3 |  반복 541 / 1327 | 시간 587[s] | 퍼플렉서티 135.54
# | 에폭 3 |  반복 561 / 1327 | 시간 591[s] | 퍼플렉서티 119.45
# | 에폭 3 |  반복 581 / 1327 | 시간 594[s] | 퍼플렉서티 105.75
# | 에폭 3 |  반복 601 / 1327 | 시간 598[s] | 퍼플렉서티 147.71
# | 에폭 3 |  반복 621 / 1327 | 시간 602[s] | 퍼플렉서티 143.00
# | 에폭 3 |  반복 641 / 1327 | 시간 605[s] | 퍼플렉서티 129.34
# | 에폭 3 |  반복 661 / 1327 | 시간 609[s] | 퍼플렉서티 119.85
# | 에폭 3 |  반복 681 / 1327 | 시간 613[s] | 퍼플렉서티 99.73
# | 에폭 3 |  반복 701 / 1327 | 시간 616[s] | 퍼플렉서티 118.69
# | 에폭 3 |  반복 721 / 1327 | 시간 620[s] | 퍼플렉서티 126.05
# | 에폭 3 |  반복 741 / 1327 | 시간 624[s] | 퍼플렉서티 107.53
# | 에폭 3 |  반복 761 / 1327 | 시간 627[s] | 퍼플렉서티 105.86
# | 에폭 3 |  반복 781 / 1327 | 시간 631[s] | 퍼플렉서티 103.73
# | 에폭 3 |  반복 801 / 1327 | 시간 635[s] | 퍼플렉서티 114.68
# | 에폭 3 |  반복 821 / 1327 | 시간 638[s] | 퍼플렉서티 115.05
# | 에폭 3 |  반복 841 / 1327 | 시간 642[s] | 퍼플렉서티 113.64
# | 에폭 3 |  반복 861 / 1327 | 시간 646[s] | 퍼플렉서티 119.26
# | 에폭 3 |  반복 881 / 1327 | 시간 649[s] | 퍼플렉서티 106.28
# | 에폭 3 |  반복 901 / 1327 | 시간 653[s] | 퍼플렉서티 132.70
# | 에폭 3 |  반복 921 / 1327 | 시간 657[s] | 퍼플렉서티 118.05
# | 에폭 3 |  반복 941 / 1327 | 시간 660[s] | 퍼플렉서티 126.30
# | 에폭 3 |  반복 961 / 1327 | 시간 664[s] | 퍼플렉서티 130.82
# | 에폭 3 |  반복 981 / 1327 | 시간 668[s] | 퍼플렉서티 122.19
# | 에폭 3 |  반복 1001 / 1327 | 시간 671[s] | 퍼플렉서티 109.13
# | 에폭 3 |  반복 1021 / 1327 | 시간 675[s] | 퍼플렉서티 128.55
# | 에폭 3 |  반복 1041 / 1327 | 시간 679[s] | 퍼플렉서티 120.95
# | 에폭 3 |  반복 1061 / 1327 | 시간 682[s] | 퍼플렉서티 103.05
# | 에폭 3 |  반복 1081 / 1327 | 시간 686[s] | 퍼플렉서티 87.73
# | 에폭 3 |  반복 1101 / 1327 | 시간 690[s] | 퍼플렉서티 95.63
# | 에폭 3 |  반복 1121 / 1327 | 시간 693[s] | 퍼플렉서티 121.57
# | 에폭 3 |  반복 1141 / 1327 | 시간 697[s] | 퍼플렉서티 115.26
# | 에폭 3 |  반복 1161 / 1327 | 시간 701[s] | 퍼플렉서티 105.24
# | 에폭 3 |  반복 1181 / 1327 | 시간 705[s] | 퍼플렉서티 111.25
# | 에폭 3 |  반복 1201 / 1327 | 시간 708[s] | 퍼플렉서티 94.05
# | 에폭 3 |  반복 1221 / 1327 | 시간 712[s] | 퍼플렉서티 88.85
# | 에폭 3 |  반복 1241 / 1327 | 시간 716[s] | 퍼플렉서티 104.91
# | 에폭 3 |  반복 1261 / 1327 | 시간 720[s] | 퍼플렉서티 103.71
# | 에폭 3 |  반복 1281 / 1327 | 시간 723[s] | 퍼플렉서티 101.36
# | 에폭 3 |  반복 1301 / 1327 | 시간 727[s] | 퍼플렉서티 126.98
# | 에폭 3 |  반복 1321 / 1327 | 시간 731[s] | 퍼플렉서티 125.25
# | 에폭 4 |  반복 1 / 1327 | 시간 732[s] | 퍼플렉서티 132.59
# | 에폭 4 |  반복 21 / 1327 | 시간 736[s] | 퍼플렉서티 120.55
# | 에폭 4 |  반복 41 / 1327 | 시간 740[s] | 퍼플렉서티 106.34
# | 에폭 4 |  반복 61 / 1327 | 시간 744[s] | 퍼플렉서티 107.18
# | 에폭 4 |  반복 81 / 1327 | 시간 748[s] | 퍼플렉서티 94.63
# | 에폭 4 |  반복 101 / 1327 | 시간 751[s] | 퍼플렉서티 86.00
# | 에폭 4 |  반복 121 / 1327 | 시간 755[s] | 퍼플렉서티 94.18
# | 에폭 4 |  반복 141 / 1327 | 시간 759[s] | 퍼플렉서티 102.38
# | 에폭 4 |  반복 161 / 1327 | 시간 763[s] | 퍼플렉서티 117.57
# | 에폭 4 |  반복 181 / 1327 | 시간 766[s] | 퍼플렉서티 128.72
# | 에폭 4 |  반복 201 / 1327 | 시간 770[s] | 퍼플렉서티 117.70
# | 에폭 4 |  반복 221 / 1327 | 시간 774[s] | 퍼플렉서티 121.02
# | 에폭 4 |  반복 241 / 1327 | 시간 778[s] | 퍼플렉서티 114.23
# | 에폭 4 |  반복 261 / 1327 | 시간 782[s] | 퍼플렉서티 113.49
# | 에폭 4 |  반복 281 / 1327 | 시간 786[s] | 퍼플렉서티 121.89
# | 에폭 4 |  반복 301 / 1327 | 시간 789[s] | 퍼플렉서티 103.23
# | 에폭 4 |  반복 321 / 1327 | 시간 793[s] | 퍼플렉서티 84.04
# | 에폭 4 |  반복 341 / 1327 | 시간 797[s] | 퍼플렉서티 100.94
# | 에폭 4 |  반복 361 / 1327 | 시간 801[s] | 퍼플렉서티 125.39
# | 에폭 4 |  반복 381 / 1327 | 시간 805[s] | 퍼플렉서티 96.72
# | 에폭 4 |  반복 401 / 1327 | 시간 808[s] | 퍼플렉서티 111.01
# | 에폭 4 |  반복 421 / 1327 | 시간 812[s] | 퍼플렉서티 94.15
# | 에폭 4 |  반복 441 / 1327 | 시간 816[s] | 퍼플렉서티 101.75
# | 에폭 4 |  반복 461 / 1327 | 시간 820[s] | 퍼플렉서티 98.41
# | 에폭 4 |  반복 481 / 1327 | 시간 823[s] | 퍼플렉서티 102.25
# | 에폭 4 |  반복 501 / 1327 | 시간 827[s] | 퍼플렉서티 108.86
# | 에폭 4 |  반복 521 / 1327 | 시간 831[s] | 퍼플렉서티 116.18
# | 에폭 4 |  반복 541 / 1327 | 시간 835[s] | 퍼플렉서티 111.68
# | 에폭 4 |  반복 561 / 1327 | 시간 839[s] | 퍼플렉서티 102.70
# | 에폭 4 |  반복 581 / 1327 | 시간 843[s] | 퍼플렉서티 89.37
# | 에폭 4 |  반복 601 / 1327 | 시간 846[s] | 퍼플렉서티 126.99
# | 에폭 4 |  반복 621 / 1327 | 시간 850[s] | 퍼플렉서티 120.97
# | 에폭 4 |  반복 641 / 1327 | 시간 854[s] | 퍼플렉서티 110.55
# | 에폭 4 |  반복 661 / 1327 | 시간 858[s] | 퍼플렉서티 102.62
# | 에폭 4 |  반복 681 / 1327 | 시간 861[s] | 퍼플렉서티 83.50
# | 에폭 4 |  반복 701 / 1327 | 시간 865[s] | 퍼플렉서티 101.95
# | 에폭 4 |  반복 721 / 1327 | 시간 869[s] | 퍼플렉서티 107.35
# | 에폭 4 |  반복 741 / 1327 | 시간 873[s] | 퍼플렉서티 94.39
# | 에폭 4 |  반복 761 / 1327 | 시간 877[s] | 퍼플렉서티 88.22
# | 에폭 4 |  반복 781 / 1327 | 시간 881[s] | 퍼플렉서티 87.31
# | 에폭 4 |  반복 801 / 1327 | 시간 884[s] | 퍼플렉서티 96.67
# | 에폭 4 |  반복 821 / 1327 | 시간 888[s] | 퍼플렉서티 99.92
# | 에폭 4 |  반복 841 / 1327 | 시간 892[s] | 퍼플렉서티 97.61
# | 에폭 4 |  반복 861 / 1327 | 시간 896[s] | 퍼플렉서티 104.63
# | 에폭 4 |  반복 881 / 1327 | 시간 899[s] | 퍼플렉서티 91.20
# | 에폭 4 |  반복 901 / 1327 | 시간 903[s] | 퍼플렉서티 115.78
# | 에폭 4 |  반복 921 / 1327 | 시간 907[s] | 퍼플렉서티 102.25
# | 에폭 4 |  반복 941 / 1327 | 시간 911[s] | 퍼플렉서티 111.15
# | 에폭 4 |  반복 961 / 1327 | 시간 914[s] | 퍼플렉서티 111.08
# | 에폭 4 |  반복 981 / 1327 | 시간 918[s] | 퍼플렉서티 105.95
# | 에폭 4 |  반복 1001 / 1327 | 시간 922[s] | 퍼플렉서티 96.05
# | 에폭 4 |  반복 1021 / 1327 | 시간 925[s] | 퍼플렉서티 112.43
# | 에폭 4 |  반복 1041 / 1327 | 시간 929[s] | 퍼플렉서티 105.29
# | 에폭 4 |  반복 1061 / 1327 | 시간 933[s] | 퍼플렉서티 89.06
# | 에폭 4 |  반복 1081 / 1327 | 시간 936[s] | 퍼플렉서티 77.41
# | 에폭 4 |  반복 1101 / 1327 | 시간 940[s] | 퍼플렉서티 79.96
# | 에폭 4 |  반복 1121 / 1327 | 시간 944[s] | 퍼플렉서티 103.29
# | 에폭 4 |  반복 1141 / 1327 | 시간 947[s] | 퍼플렉서티 100.04
# | 에폭 4 |  반복 1161 / 1327 | 시간 951[s] | 퍼플렉서티 90.21
# | 에폭 4 |  반복 1181 / 1327 | 시간 955[s] | 퍼플렉서티 95.54
# | 에폭 4 |  반복 1201 / 1327 | 시간 958[s] | 퍼플렉서티 84.03
# | 에폭 4 |  반복 1221 / 1327 | 시간 962[s] | 퍼플렉서티 76.08
# | 에폭 4 |  반복 1241 / 1327 | 시간 966[s] | 퍼플렉서티 90.72
# | 에폭 4 |  반복 1261 / 1327 | 시간 969[s] | 퍼플렉서티 92.64
# | 에폭 4 |  반복 1281 / 1327 | 시간 973[s] | 퍼플렉서티 89.94
# | 에폭 4 |  반복 1301 / 1327 | 시간 977[s] | 퍼플렉서티 109.84
# | 에폭 4 |  반복 1321 / 1327 | 시간 980[s] | 퍼플렉서티 109.80
# C:\Users\twino\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\twino\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48373 (\N{HANGUL SYLLABLE BOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\twino\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54140 (\N{HANGUL SYLLABLE PEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\twino\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\twino\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47113 (\N{HANGUL SYLLABLE REG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\twino\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\twino\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54000 (\N{HANGUL SYLLABLE TI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 퍼플렉서티 평가 중 ...
# 234 / 235
# 테스트 퍼플렉서티:  135.13983078032493
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Deep_Learning_From_Scratch2\20231003 - 6장_게이트가 추가된 RNN.ipynb Cell 11 line 4
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%206%EC%9E%A5_%EA%B2%8C%EC%9D%B4%ED%8A%B8%EA%B0%80%20%EC%B6%94%EA%B0%80%EB%90%9C%20RNN.ipynb#X13sZmlsZQ%3D%3D?line=36'>37</a> print('테스트 퍼플렉서티: ', ppl_test)
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%206%EC%9E%A5_%EA%B2%8C%EC%9D%B4%ED%8A%B8%EA%B0%80%20%EC%B6%94%EA%B0%80%EB%90%9C%20RNN.ipynb#X13sZmlsZQ%3D%3D?line=38'>39</a> # 매게변수 저장
# ---> <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%206%EC%9E%A5_%EA%B2%8C%EC%9D%B4%ED%8A%B8%EA%B0%80%20%EC%B6%94%EA%B0%80%EB%90%9C%20RNN.ipynb#X13sZmlsZQ%3D%3D?line=39'>40</a> model.save_params()
#
# File f:\Deep_Learning_From_Scratch2\common\base_model.py:25, in BaseModel.save_params(self, file_name)
#      22     file_name = self.__class__.__name__ + '.pkl'
#      24 params = [p.astype(np.float16) for p in self.params]
# ---> 25 if GPU:
#      26     params = [to_cpu(p) for p in params]
#      28 with open(file_name, 'wb') as f:
#
# NameError: name 'GPU' is not defined

# %% [markdown]
# ## 개선된 LSTM 구현
# 1. LSTM 계층의 다층화
# 2. 드롭아웃 사용 (깊이 방향으로만 적용)
# 3. 가중치 공유 (Embedding 계층과 Affine 계층에서 가중치 공유)

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.time_layers import *
import numpy as np
from common.base_model import BaseModel

class BetterRnnlm(BaseModel):
    '''
     LSTM 계층을 2개 사용하고 각 층에 드롭아웃을 적용한 모델이다.
     아래 [1]에서 제안한 모델을 기초로 하였고, [2]와 [3]의 가중치 공유(weight tying)를 적용했다.

     [1] Recurrent Neural Network Regularization (https://arxiv.org/abs/1409.2329)
     [2] Using the Output Embedding to Improve Language Models (https://arxiv.org/abs/1608.05859)
     [3] Tying Word Vectors and Word Classifiers (https://arxiv.org/pdf/1611.01462.pdf)
    '''
    def __init__(self, vocab_size=10000, wordvec_size=650,
                 hidden_size=650, dropout_ratio=0.5):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx1 = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh1 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b1 = np.zeros(4 * H).astype('f')
        lstm_Wx2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_Wh2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b2 = np.zeros(4 * H).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.layers = [
            TimeEmbedding(embed_W),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx1, lstm_Wh1, lstm_b1, stateful=True),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx2, lstm_Wh2, lstm_b2, stateful=True),
            TimeDropout(dropout_ratio),
            TimeAffine(embed_W.T, affine_b)  # 가중치 공유
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layers = [self.layers[2], self.layers[4]]
        self.drop_layers = [self.layers[1], self.layers[3], self.layers[5]]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs, train_flg=False):
        for layer in self.drop_layers:
            layer.train_flg = train_flg

        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts, train_flg=True):
        score = self.predict(xs, train_flg)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        for layer in self.lstm_layers:
            layer.reset_state()

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common import config
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity, to_gpu
from dataset import ptb
# from better_rnnlm import BetterRnnlm


# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 650
hidden_size = 650
time_size = 35
lr = 20.0
max_epoch = 40
max_grad = 0.25
dropout = 0.5

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_val, _, _ = ptb.load_data('val')
corpus_test, _, _ = ptb.load_data('test')

if config.GPU:
    corpus = to_gpu(corpus)
    corpus_val = to_gpu(corpus_val)
    corpus_test = to_gpu(corpus_test)

vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

model = BetterRnnlm(vocab_size, wordvec_size, hidden_size, dropout)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

best_ppl = float('inf')
for epoch in range(max_epoch):
    trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size,
                time_size=time_size, max_grad=max_grad)

    model.reset_state()
    ppl = eval_perplexity(model, corpus_val)
    print('검증 퍼플렉서티: ', ppl)

    if best_ppl > ppl:
        best_ppl = ppl
        model.save_params()
    else:
        lr /= 4.0
        optimizer.lr = lr

    model.reset_state()
    print('-' * 50)


# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)
# Out:
# Downloading ptb.valid.txt ...
# Done
# | 에폭 1 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 9999.64
# | 에폭 1 |  반복 21 / 1327 | 시간 32[s] | 퍼플렉서티 3446.07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# f:\Deep_Learning_From_Scratch2\20231003 - 6장_게이트가 추가된 RNN.ipynb Cell 14 line 4
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%206%EC%9E%A5_%EA%B2%8C%EC%9D%B4%ED%8A%B8%EA%B0%80%20%EC%B6%94%EA%B0%80%EB%90%9C%20RNN.ipynb#X21sZmlsZQ%3D%3D?line=39'>40</a> best_ppl = float('inf')
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%206%EC%9E%A5_%EA%B2%8C%EC%9D%B4%ED%8A%B8%EA%B0%80%20%EC%B6%94%EA%B0%80%EB%90%9C%20RNN.ipynb#X21sZmlsZQ%3D%3D?line=40'>41</a> for epoch in range(max_epoch):
# ---> <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%206%EC%9E%A5_%EA%B2%8C%EC%9D%B4%ED%8A%B8%EA%B0%80%20%EC%B6%94%EA%B0%80%EB%90%9C%20RNN.ipynb#X21sZmlsZQ%3D%3D?line=41'>42</a>     trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size,
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%206%EC%9E%A5_%EA%B2%8C%EC%9D%B4%ED%8A%B8%EA%B0%80%20%EC%B6%94%EA%B0%80%EB%90%9C%20RNN.ipynb#X21sZmlsZQ%3D%3D?line=42'>43</a>                 time_size=time_size, max_grad=max_grad)
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%206%EC%9E%A5_%EA%B2%8C%EC%9D%B4%ED%8A%B8%EA%B0%80%20%EC%B6%94%EA%B0%80%EB%90%9C%20RNN.ipynb#X21sZmlsZQ%3D%3D?line=44'>45</a>     model.reset_state()
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%206%EC%9E%A5_%EA%B2%8C%EC%9D%B4%ED%8A%B8%EA%B0%80%20%EC%B6%94%EA%B0%80%EB%90%9C%20RNN.ipynb#X21sZmlsZQ%3D%3D?line=45'>46</a>     ppl = eval_perplexity(model, corpus_val)
#
# File f:\Deep_Learning_From_Scratch2\common\trainer.py:115, in RnnlmTrainer.fit(self, xs, ts, max_epoch, batch_size, time_size, max_grad, eval_interval)
#     113 if max_grad is not None:
#     114     clip_grads(grads, max_grad)
# --> 115 optimizer.update(params, grads)
#     116 total_loss += loss
#     117 loss_count += 1
#
# File f:\Deep_Learning_From_Scratch2\common\optimizer.py:15, in SGD.update(self, params, grads)
#      13 def update(self, params, grads):
#      14     for i in range(len(params)):
# ---> 15         params[i] -= self.lr * grads[i]
#
# KeyboardInterrupt:
