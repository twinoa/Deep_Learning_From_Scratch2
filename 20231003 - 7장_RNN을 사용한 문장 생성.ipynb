# %% [markdown]
# ## 문장 생성 구현

# %%
import sys
sys.path.append('..')
import numpy as np
from common.functions import softmax
from rnnlm import Rnnlm
from better_rnnlm import BetterRnnlm

class RnnlmGen(Rnnlm):
    def generate(self, start_id, skip_ids = None, sample_size=100):
        word_ids = [start_id]

        x = start_id
        while len(word_ids) < sample_size:
            x = np.array(x).reshape(1, 1)
            score = self.predict(x)
            p = softmax(score.flatten())

            sampled = np.random.choice(len(p), size=1, p=p)
            if (skip_ids is None) or (sampled not in skip_ids):
                x = sampled
                word_ids.append(int(x))

        return word_ids

# %%
import sys
sys.path.append('..')
from dataset import ptb

corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)
corpus_size = len(corpus)

model = RnnlmGen()
model.load_params('Rnnlm.pkl')

# 시작(start) 문자와 건너뜀(skip) 문자 설정
start_word = 'you'
start_id = word_to_id[start_word]
skip_words = ['N', '<unk>', '$']
skip_ids = [word_to_id[w] for w in skip_words]

# 문장 생성
word_ids = model.generate(start_id, skip_ids)
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')
print(txt)
# Out:
# you tube he even consented to forget for quotations to play productivity today and them than late to the moment.
#  first company said silver along at a leveraged buy-out of raw cancer.
#  require more money and far the last educational policy is n't aimed at all but contended or instead strategy for the flag it does n't come down.
#  mr. honecker wants to have a matter.
#  mr. sharon said the participation my cause in the kansas city had become assured on his job.
#  but mr. roman has received a new loan campaign which is strong

# %% [markdown]
# ## 덧셈 데이터셋으로 seq2seq 구현

# %%
import sys
sys.path.append('..')
from dataset import sequence

(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt', seed=1984)
char_to_id, id_to_char = sequence.get_vocab()

print(x_train.shape, t_train.shape)
print(x_test.shape, t_test.shape)

print(x_train[0])
print(t_train[0])

print(''.join([id_to_char[c] for c in x_train[0]]))
print(''.join([id_to_char[c] for c in t_train[0]]))
# Out:
# (45000, 7) (45000, 5)
# (5000, 7) (5000, 5)
# [ 3  0  2  0  0 11  5]
# [ 6  0 11  7  5]
# 71+118
# _189

# %%
class Encoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=False)

        self.params = self.embed.parmas + self.lstm.params
        self.grads = self.embed.grads + self.lstm.grads
        self.hs = None

    def forward(self, xs):
        xs = self.embed.forward(xs)
        hs = self.lstm.forward(xs)
        self.hs = hs
        return hs[:, -1, :]
    
    def backward(self, dh):
        dhs = np.zeros_like(self.hs)
        dhs[:, -1, :] = dh

        dout = self.lstm.backward(dhs)
        dout = self.embed.backward(dout)
        return dout

# %%
class Decoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)
        self.params, self.grads = [], []
        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads

        def forward(self, xs, h):
            self.lstm.set_state(h)

            out = self.embed.forward(xs)
            out = self.lstm.forward(out)
            score = self.affine.forward(out)
            return score
        
        def backward(self, dscore):
            dout = self.affine.backward(dscore)
            dout = self.lstm.backward(dout)
            dout = self.embed.backward(dout)
            dh = self.lstm.dh
            return dh
        
        def generate(self, h, start_id, sample_size):
            sampled = []
            sample_id = start_id
            self.lstm.set_state(h)

            for _ in range(sample_size):
                x = np.array(sample_id).reshape((1, 1))
                out = self.embed.forward(x)
                out = self.lstm.forward(out)
                score = self.affine.forward(out)

                sample_id = np.argmax(score.flatten())
                sampled.append(int(sample_id))

            return sampled

# %%
from common.base_model import BaseModel

class Seq2seq(BaseModel):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = Decoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

    def forward(self, xs, ts):
        decoder_xs, decoder_ts = ts[:, :-1], ts[:, 1:]
        h = self.encoder.forward(xs)
        score = self.decoder.forward(decoder_xs, h)
        loss = self.softmax.forward(score, decoder_ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.softmax.backward(dout)
        dh = self.decoder.backward(dout)
        dout = self.encoder.backward(dh)
        return dout
    
    def generate(self, xs, start_id, sample_size):
        h = self.encoder.forward(xs)
        sampled = self.decoder.generate(h, start_id, sample_size)
        return sampled

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from seq2seq import Seq2seq
from peeky_seq2seq import PeekySeq2seq

# 데이터셋 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
char_to_id, id_to_char = sequence.get_vocab()

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# 모델 / 옵티마이저 / 트레이너 생성
# model = Seq2seq(vocab_size, wordvec_size, hidden_size)
model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch = 1, 
                batch_size = batch_size, max_grad = max_grad)
    
    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)
        
    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.57
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.48
# | 에폭 1 |  반복 41 / 351 | 시간 1[s] | 손실 2.20
# | 에폭 1 |  반복 61 / 351 | 시간 1[s] | 손실 1.99
# | 에폭 1 |  반복 81 / 351 | 시간 2[s] | 손실 1.89
# | 에폭 1 |  반복 101 / 351 | 시간 2[s] | 손실 1.82
# | 에폭 1 |  반복 121 / 351 | 시간 3[s] | 손실 1.82
# | 에폭 1 |  반복 141 / 351 | 시간 3[s] | 손실 1.80
# | 에폭 1 |  반복 161 / 351 | 시간 4[s] | 손실 1.79
# | 에폭 1 |  반복 181 / 351 | 시간 5[s] | 손실 1.78
# | 에폭 1 |  반복 201 / 351 | 시간 5[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 6[s] | 손실 1.76
# | 에폭 1 |  반복 241 / 351 | 시간 6[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 7[s] | 손실 1.75
# | 에폭 1 |  반복 281 / 351 | 시간 7[s] | 손실 1.74
# | 에폭 1 |  반복 301 / 351 | 시간 8[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 8[s] | 손실 1.73
# | 에폭 1 |  반복 341 / 351 | 시간 9[s] | 손실 1.73
# Q   58+77
# T 162
# X 100
# ---
# Q 461+579
# T 1139
# X 1013
# ---
# Q  48+285
# T 666
# X 102
# ---
# Q   551+8
# T 163
# X 100
# ---
# Q  55+763
# T 422
# X 1023
# ---
# Q 752+006
# T 857
# X 1023
# ---
# Q 292+167
# T 1053
# X 1023
# ---
# Q 795+038
# T 1427
# X 1111
# ---
# Q  838+62
# T 864
# X 102
# ---
# Q  39+341
# T 236
# X 102
# ---
# 검증 정확도 0.280%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.71
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.71
# | 에폭 2 |  반복 41 / 351 | 시간 1[s] | 손실 1.71
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.71
# | 에폭 2 |  반복 81 / 351 | 시간 2[s] | 손실 1.70
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 1.68
# | 에폭 2 |  반복 121 / 351 | 시간 3[s] | 손실 1.69
# | 에폭 2 |  반복 141 / 351 | 시간 3[s] | 손실 1.68
# | 에폭 2 |  반복 161 / 351 | 시간 4[s] | 손실 1.67
# | 에폭 2 |  반복 181 / 351 | 시간 4[s] | 손실 1.67
# | 에폭 2 |  반복 201 / 351 | 시간 5[s] | 손실 1.65
# | 에폭 2 |  반복 221 / 351 | 시간 6[s] | 손실 1.65
# | 에폭 2 |  반복 241 / 351 | 시간 6[s] | 손실 1.65
# | 에폭 2 |  반복 261 / 351 | 시간 7[s] | 손실 1.63
# | 에폭 2 |  반복 281 / 351 | 시간 7[s] | 손실 1.62
# | 에폭 2 |  반복 301 / 351 | 시간 8[s] | 손실 1.61
# | 에폭 2 |  반복 321 / 351 | 시간 8[s] | 손실 1.61
# | 에폭 2 |  반복 341 / 351 | 시간 9[s] | 손실 1.60
# Q   58+77
# T 162
# X 100
# ---
# Q 461+579
# T 1139
# X 1200
# ---
# Q  48+285
# T 666
# X 690
# ---
# Q   551+8
# T 163
# X 100
# ---
# Q  55+763
# T 422
# X 690
# ---
# Q 752+006
# T 857
# X 999
# ---
# Q 292+167
# T 1053
# X 1029
# ---
# Q 795+038
# T 1427
# X 1240
# ---
# Q  838+62
# T 864
# X 792
# ---
# Q  39+341
# T 236
# X 290
# ---
# 검증 정확도 0.400%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.58
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.59
# | 에폭 3 |  반복 41 / 351 | 시간 1[s] | 손실 1.58
# | 에폭 3 |  반복 61 / 351 | 시간 1[s] | 손실 1.56
# | 에폭 3 |  반복 81 / 351 | 시간 2[s] | 손실 1.55
# | 에폭 3 |  반복 101 / 351 | 시간 2[s] | 손실 1.53
# | 에폭 3 |  반복 121 / 351 | 시간 3[s] | 손실 1.51
# | 에폭 3 |  반복 141 / 351 | 시간 3[s] | 손실 1.50
# | 에폭 3 |  반복 161 / 351 | 시간 4[s] | 손실 1.49
# | 에폭 3 |  반복 181 / 351 | 시간 4[s] | 손실 1.47
# | 에폭 3 |  반복 201 / 351 | 시간 5[s] | 손실 1.46
# | 에폭 3 |  반복 221 / 351 | 시간 6[s] | 손실 1.43
# | 에폭 3 |  반복 241 / 351 | 시간 6[s] | 손실 1.42
# | 에폭 3 |  반복 261 / 351 | 시간 7[s] | 손실 1.41
# | 에폭 3 |  반복 281 / 351 | 시간 7[s] | 손실 1.39
# | 에폭 3 |  반복 301 / 351 | 시간 8[s] | 손실 1.37
# | 에폭 3 |  반복 321 / 351 | 시간 8[s] | 손실 1.36
# | 에폭 3 |  반복 341 / 351 | 시간 9[s] | 손실 1.35
# Q   58+77
# T 162
# X 154
# ---
# Q 461+579
# T 1139
# X 1033
# ---
# Q  48+285
# T 666
# X 644
# ---
# Q   551+8
# T 163
# X 161
# ---
# Q  55+763
# T 422
# X 433
# ---
# Q 752+006
# T 857
# X 818
# ---
# Q 292+167
# T 1053
# X 1018
# ---
# Q 795+038
# T 1427
# X 1344
# ---
# Q  838+62
# T 864
# X 834
# ---
# Q  39+341
# T 236
# X 211
# ---
# 검증 정확도 1.600%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.32
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.32
# | 에폭 4 |  반복 41 / 351 | 시간 1[s] | 손실 1.30
# | 에폭 4 |  반복 61 / 351 | 시간 1[s] | 손실 1.30
# | 에폭 4 |  반복 81 / 351 | 시간 2[s] | 손실 1.28
# | 에폭 4 |  반복 101 / 351 | 시간 2[s] | 손실 1.27
# | 에폭 4 |  반복 121 / 351 | 시간 3[s] | 손실 1.25
# | 에폭 4 |  반복 141 / 351 | 시간 3[s] | 손실 1.24
# | 에폭 4 |  반복 161 / 351 | 시간 4[s] | 손실 1.22
# | 에폭 4 |  반복 181 / 351 | 시간 4[s] | 손실 1.21
# | 에폭 4 |  반복 201 / 351 | 시간 5[s] | 손실 1.20
# | 에폭 4 |  반복 221 / 351 | 시간 6[s] | 손실 1.20
# | 에폭 4 |  반복 241 / 351 | 시간 6[s] | 손실 1.17
# | 에폭 4 |  반복 261 / 351 | 시간 7[s] | 손실 1.16
# | 에폭 4 |  반복 281 / 351 | 시간 7[s] | 손실 1.14
# | 에폭 4 |  반복 301 / 351 | 시간 8[s] | 손실 1.12
# | 에폭 4 |  반복 321 / 351 | 시간 8[s] | 손실 1.11
# | 에폭 4 |  반복 341 / 351 | 시간 9[s] | 손실 1.10
# Q   58+77
# T 162
# X 158
# ---
# Q 461+579
# T 1139
# X 1123
# ---
# Q  48+285
# T 666
# X 657
# ---
# Q   551+8
# T 163
# X 165
# ---
# Q  55+763
# T 422
# X 423
# ---
# Q 752+006
# T 857
# X 777
# ---
# Q 292+167
# T 1053
# X 1023
# ---
# Q 795+038
# T 1427
# X 1388
# ---
# Q  838+62
# T 864
# X 887
# ---
# Q  39+341
# T 236
# X 223
# ---
# 검증 정확도 5.140%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.08
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 1.07
# | 에폭 5 |  반복 41 / 351 | 시간 1[s] | 손실 1.05
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 1.04
# | 에폭 5 |  반복 81 / 351 | 시간 2[s] | 손실 1.02
# | 에폭 5 |  반복 101 / 351 | 시간 2[s] | 손실 1.01
# | 에폭 5 |  반복 121 / 351 | 시간 3[s] | 손실 1.00
# | 에폭 5 |  반복 141 / 351 | 시간 3[s] | 손실 0.99
# | 에폭 5 |  반복 161 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 5 |  반복 181 / 351 | 시간 4[s] | 손실 0.96
# | 에폭 5 |  반복 201 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 5 |  반복 221 / 351 | 시간 6[s] | 손실 0.94
# | 에폭 5 |  반복 241 / 351 | 시간 6[s] | 손실 0.92
# | 에폭 5 |  반복 261 / 351 | 시간 7[s] | 손실 0.91
# | 에폭 5 |  반복 281 / 351 | 시간 7[s] | 손실 0.90
# | 에폭 5 |  반복 301 / 351 | 시간 8[s] | 손실 0.89
# | 에폭 5 |  반복 321 / 351 | 시간 8[s] | 손실 0.88
# | 에폭 5 |  반복 341 / 351 | 시간 9[s] | 손실 0.87
# Q   58+77
# T 162
# X 160
# ---
# Q 461+579
# T 1139
# X 1135
# ---
# Q  48+285
# T 666
# X 668
# ---
# Q   551+8
# T 163
# X 169
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 861
# ---
# Q 292+167
# T 1053
# X 1045
# ---
# Q 795+038
# T 1427
# X 1324
# ---
# Q  838+62
# T 864
# X 861
# ---
# Q  39+341
# T 236
# X 239
# ---
# 검증 정확도 9.380%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 6 |  반복 41 / 351 | 시간 1[s] | 손실 0.83
# | 에폭 6 |  반복 61 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 6 |  반복 81 / 351 | 시간 2[s] | 손실 0.82
# | 에폭 6 |  반복 101 / 351 | 시간 2[s] | 손실 0.81
# | 에폭 6 |  반복 121 / 351 | 시간 3[s] | 손실 0.80
# | 에폭 6 |  반복 141 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 6 |  반복 161 / 351 | 시간 4[s] | 손실 0.78
# | 에폭 6 |  반복 181 / 351 | 시간 4[s] | 손실 0.77
# | 에폭 6 |  반복 201 / 351 | 시간 5[s] | 손실 0.76
# | 에폭 6 |  반복 221 / 351 | 시간 6[s] | 손실 0.76
# | 에폭 6 |  반복 241 / 351 | 시간 6[s] | 손실 0.74
# | 에폭 6 |  반복 261 / 351 | 시간 7[s] | 손실 0.74
# | 에폭 6 |  반복 281 / 351 | 시간 7[s] | 손실 0.73
# | 에폭 6 |  반복 301 / 351 | 시간 8[s] | 손실 0.72
# | 에폭 6 |  반복 321 / 351 | 시간 8[s] | 손실 0.72
# | 에폭 6 |  반복 341 / 351 | 시간 9[s] | 손실 0.71
# Q   58+77
# T 162
# X 163
# ---
# Q 461+579
# T 1139
# X 1138
# ---
# Q  48+285
# T 666
# X 668
# ---
# Q   551+8
# T 163
# X 166
# ---
# Q  55+763
# T 422
# X 423
# ---
# Q 752+006
# T 857
# X 858
# ---
# Q 292+167
# T 1053
# X 1048
# ---
# Q 795+038
# T 1427
# X 1428
# ---
# Q  838+62
# T 864
# X 873
# ---
# Q  39+341
# T 236
# X 239
# ---
# 검증 정확도 15.040%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.68
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 0.69
# | 에폭 7 |  반복 41 / 351 | 시간 1[s] | 손실 0.67
# | 에폭 7 |  반복 61 / 351 | 시간 1[s] | 손실 0.66
# | 에폭 7 |  반복 81 / 351 | 시간 2[s] | 손실 0.66
# | 에폭 7 |  반복 101 / 351 | 시간 2[s] | 손실 0.65
# | 에폭 7 |  반복 121 / 351 | 시간 3[s] | 손실 0.65
# | 에폭 7 |  반복 141 / 351 | 시간 3[s] | 손실 0.64
# | 에폭 7 |  반복 161 / 351 | 시간 4[s] | 손실 0.63
# | 에폭 7 |  반복 181 / 351 | 시간 4[s] | 손실 0.61
# | 에폭 7 |  반복 201 / 351 | 시간 5[s] | 손실 0.61
# | 에폭 7 |  반복 221 / 351 | 시간 5[s] | 손실 0.60
# | 에폭 7 |  반복 241 / 351 | 시간 6[s] | 손실 0.57
# | 에폭 7 |  반복 261 / 351 | 시간 7[s] | 손실 0.57
# | 에폭 7 |  반복 281 / 351 | 시간 7[s] | 손실 0.57
# | 에폭 7 |  반복 301 / 351 | 시간 8[s] | 손실 0.55
# | 에폭 7 |  반복 321 / 351 | 시간 8[s] | 손실 0.54
# | 에폭 7 |  반복 341 / 351 | 시간 9[s] | 손실 0.53
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# X 665
# ---
# Q   551+8
# T 163
# X 156
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 858
# ---
# Q 292+167
# T 1053
# X 1052
# ---
# Q 795+038
# T 1427
# X 1428
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# X 235
# ---
# 검증 정확도 39.100%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.51
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 0.50
# | 에폭 8 |  반복 41 / 351 | 시간 1[s] | 손실 0.49
# | 에폭 8 |  반복 61 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 8 |  반복 81 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 8 |  반복 101 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 8 |  반복 121 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 8 |  반복 141 / 351 | 시간 3[s] | 손실 0.44
# | 에폭 8 |  반복 161 / 351 | 시간 4[s] | 손실 0.41
# | 에폭 8 |  반복 181 / 351 | 시간 4[s] | 손실 0.42
# | 에폭 8 |  반복 201 / 351 | 시간 5[s] | 손실 0.41
# | 에폭 8 |  반복 221 / 351 | 시간 6[s] | 손실 0.40
# | 에폭 8 |  반복 241 / 351 | 시간 6[s] | 손실 0.39
# | 에폭 8 |  반복 261 / 351 | 시간 7[s] | 손실 0.37
# | 에폭 8 |  반복 281 / 351 | 시간 7[s] | 손실 0.36
# | 에폭 8 |  반복 301 / 351 | 시간 8[s] | 손실 0.36
# | 에폭 8 |  반복 321 / 351 | 시간 8[s] | 손실 0.35
# | 에폭 8 |  반복 341 / 351 | 시간 9[s] | 손실 0.34
# Q   58+77
# T 162
# X 161
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# X 657
# ---
# Q   551+8
# T 163
# X 155
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# X 1438
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 65.060%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.32
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 9 |  반복 41 / 351 | 시간 1[s] | 손실 0.31
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 0.31
# | 에폭 9 |  반복 81 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 9 |  반복 101 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 9 |  반복 121 / 351 | 시간 3[s] | 손실 0.29
# | 에폭 9 |  반복 141 / 351 | 시간 3[s] | 손실 0.27
# | 에폭 9 |  반복 161 / 351 | 시간 4[s] | 손실 0.27
# | 에폭 9 |  반복 181 / 351 | 시간 4[s] | 손실 0.26
# | 에폭 9 |  반복 201 / 351 | 시간 5[s] | 손실 0.25
# | 에폭 9 |  반복 221 / 351 | 시간 6[s] | 손실 0.25
# | 에폭 9 |  반복 241 / 351 | 시간 6[s] | 손실 0.24
# | 에폭 9 |  반복 261 / 351 | 시간 7[s] | 손실 0.24
# | 에폭 9 |  반복 281 / 351 | 시간 7[s] | 손실 0.23
# | 에폭 9 |  반복 301 / 351 | 시간 8[s] | 손실 0.22
# | 에폭 9 |  반복 321 / 351 | 시간 8[s] | 손실 0.22
# | 에폭 9 |  반복 341 / 351 | 시간 9[s] | 손실 0.21
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1140
# ---
# Q  48+285
# T 666
# X 657
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 83.280%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.22
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.20
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 0.20
# | 에폭 10 |  반복 61 / 351 | 시간 1[s] | 손실 0.20
# | 에폭 10 |  반복 81 / 351 | 시간 2[s] | 손실 0.18
# | 에폭 10 |  반복 101 / 351 | 시간 2[s] | 손실 0.17
# | 에폭 10 |  반복 121 / 351 | 시간 3[s] | 손실 0.18
# | 에폭 10 |  반복 141 / 351 | 시간 3[s] | 손실 0.17
# | 에폭 10 |  반복 161 / 351 | 시간 4[s] | 손실 0.17
# | 에폭 10 |  반복 181 / 351 | 시간 4[s] | 손실 0.17
# | 에폭 10 |  반복 201 / 351 | 시간 5[s] | 손실 0.17
# | 에폭 10 |  반복 221 / 351 | 시간 6[s] | 손실 0.16
# | 에폭 10 |  반복 241 / 351 | 시간 6[s] | 손실 0.15
# | 에폭 10 |  반복 261 / 351 | 시간 7[s] | 손실 0.15
# | 에폭 10 |  반복 281 / 351 | 시간 7[s] | 손실 0.15
# | 에폭 10 |  반복 301 / 351 | 시간 8[s] | 손실 0.15
# | 에폭 10 |  반복 321 / 351 | 시간 8[s] | 손실 0.14
# | 에폭 10 |  반복 341 / 351 | 시간 9[s] | 손실 0.14
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# X 656
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 88.400%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.13
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.13
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 0.13
# | 에폭 11 |  반복 61 / 351 | 시간 1[s] | 손실 0.12
# | 에폭 11 |  반복 81 / 351 | 시간 2[s] | 손실 0.12
# | 에폭 11 |  반복 101 / 351 | 시간 2[s] | 손실 0.12
# | 에폭 11 |  반복 121 / 351 | 시간 3[s] | 손실 0.11
# | 에폭 11 |  반복 141 / 351 | 시간 3[s] | 손실 0.12
# | 에폭 11 |  반복 161 / 351 | 시간 4[s] | 손실 0.11
# | 에폭 11 |  반복 181 / 351 | 시간 4[s] | 손실 0.11
# | 에폭 11 |  반복 201 / 351 | 시간 5[s] | 손실 0.12
# | 에폭 11 |  반복 221 / 351 | 시간 6[s] | 손실 0.11
# | 에폭 11 |  반복 241 / 351 | 시간 6[s] | 손실 0.11
# | 에폭 11 |  반복 261 / 351 | 시간 7[s] | 손실 0.10
# | 에폭 11 |  반복 281 / 351 | 시간 7[s] | 손실 0.10
# | 에폭 11 |  반복 301 / 351 | 시간 8[s] | 손실 0.10
# | 에폭 11 |  반복 321 / 351 | 시간 8[s] | 손실 0.09
# | 에폭 11 |  반복 341 / 351 | 시간 9[s] | 손실 0.09
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 90.940%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.09
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.09
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 0.09
# | 에폭 12 |  반복 61 / 351 | 시간 2[s] | 손실 0.09
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 0.09
# | 에폭 12 |  반복 101 / 351 | 시간 3[s] | 손실 0.08
# | 에폭 12 |  반복 121 / 351 | 시간 3[s] | 손실 0.08
# | 에폭 12 |  반복 141 / 351 | 시간 4[s] | 손실 0.08
# | 에폭 12 |  반복 161 / 351 | 시간 5[s] | 손실 0.08
# | 에폭 12 |  반복 181 / 351 | 시간 6[s] | 손실 0.08
# | 에폭 12 |  반복 201 / 351 | 시간 6[s] | 손실 0.08
# | 에폭 12 |  반복 221 / 351 | 시간 7[s] | 손실 0.09
# | 에폭 12 |  반복 241 / 351 | 시간 8[s] | 손실 0.09
# | 에폭 12 |  반복 261 / 351 | 시간 11[s] | 손실 0.09
# | 에폭 12 |  반복 281 / 351 | 시간 12[s] | 손실 0.08
# | 에폭 12 |  반복 301 / 351 | 시간 13[s] | 손실 0.08
# | 에폭 12 |  반복 321 / 351 | 시간 14[s] | 손실 0.07
# | 에폭 12 |  반복 341 / 351 | 시간 14[s] | 손실 0.08
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 92.240%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.07
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.07
# | 에폭 13 |  반복 41 / 351 | 시간 1[s] | 손실 0.07
# | 에폭 13 |  반복 61 / 351 | 시간 1[s] | 손실 0.07
# | 에폭 13 |  반복 81 / 351 | 시간 2[s] | 손실 0.06
# | 에폭 13 |  반복 101 / 351 | 시간 3[s] | 손실 0.06
# | 에폭 13 |  반복 121 / 351 | 시간 3[s] | 손실 0.07
# | 에폭 13 |  반복 141 / 351 | 시간 4[s] | 손실 0.06
# | 에폭 13 |  반복 161 / 351 | 시간 5[s] | 손실 0.06
# | 에폭 13 |  반복 181 / 351 | 시간 5[s] | 손실 0.06
# | 에폭 13 |  반복 201 / 351 | 시간 6[s] | 손실 0.06
# | 에폭 13 |  반복 221 / 351 | 시간 6[s] | 손실 0.06
# | 에폭 13 |  반복 241 / 351 | 시간 7[s] | 손실 0.06
# | 에폭 13 |  반복 261 / 351 | 시간 8[s] | 손실 0.06
# | 에폭 13 |  반복 281 / 351 | 시간 8[s] | 손실 0.06
# | 에폭 13 |  반복 301 / 351 | 시간 9[s] | 손실 0.05
# | 에폭 13 |  반복 321 / 351 | 시간 9[s] | 손실 0.05
# | 에폭 13 |  반복 341 / 351 | 시간 10[s] | 손실 0.06
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 94.380%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 14 |  반복 41 / 351 | 시간 1[s] | 손실 0.05
# | 에폭 14 |  반복 61 / 351 | 시간 1[s] | 손실 0.05
# | 에폭 14 |  반복 81 / 351 | 시간 2[s] | 손실 0.05
# | 에폭 14 |  반복 101 / 351 | 시간 2[s] | 손실 0.05
# | 에폭 14 |  반복 121 / 351 | 시간 3[s] | 손실 0.05
# | 에폭 14 |  반복 141 / 351 | 시간 4[s] | 손실 0.05
# | 에폭 14 |  반복 161 / 351 | 시간 4[s] | 손실 0.05
# | 에폭 14 |  반복 181 / 351 | 시간 5[s] | 손실 0.05
# | 에폭 14 |  반복 201 / 351 | 시간 5[s] | 손실 0.05
# | 에폭 14 |  반복 221 / 351 | 시간 6[s] | 손실 0.06
# | 에폭 14 |  반복 241 / 351 | 시간 7[s] | 손실 0.06
# | 에폭 14 |  반복 261 / 351 | 시간 7[s] | 손실 0.07
# | 에폭 14 |  반복 281 / 351 | 시간 8[s] | 손실 0.07
# | 에폭 14 |  반복 301 / 351 | 시간 8[s] | 손실 0.07
# | 에폭 14 |  반복 321 / 351 | 시간 9[s] | 손실 0.05
# | 에폭 14 |  반복 341 / 351 | 시간 9[s] | 손실 0.04
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 95.780%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 15 |  반복 41 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 15 |  반복 61 / 351 | 시간 1[s] | 손실 0.05
# | 에폭 15 |  반복 81 / 351 | 시간 2[s] | 손실 0.04
# | 에폭 15 |  반복 101 / 351 | 시간 2[s] | 손실 0.04
# | 에폭 15 |  반복 121 / 351 | 시간 3[s] | 손실 0.04
# | 에폭 15 |  반복 141 / 351 | 시간 4[s] | 손실 0.04
# | 에폭 15 |  반복 161 / 351 | 시간 4[s] | 손실 0.05
# | 에폭 15 |  반복 181 / 351 | 시간 5[s] | 손실 0.05
# | 에폭 15 |  반복 201 / 351 | 시간 5[s] | 손실 0.04
# | 에폭 15 |  반복 221 / 351 | 시간 6[s] | 손실 0.04
# | 에폭 15 |  반복 241 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 15 |  반복 261 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 15 |  반복 281 / 351 | 시간 8[s] | 손실 0.06
# | 에폭 15 |  반복 301 / 351 | 시간 8[s] | 손실 0.06
# | 에폭 15 |  반복 321 / 351 | 시간 9[s] | 손실 0.05
# | 에폭 15 |  반복 341 / 351 | 시간 10[s] | 손실 0.04
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1149
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 164
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 93.720%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 16 |  반복 41 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 16 |  반복 61 / 351 | 시간 1[s] | 손실 0.03
# | 에폭 16 |  반복 81 / 351 | 시간 2[s] | 손실 0.03
# | 에폭 16 |  반복 101 / 351 | 시간 2[s] | 손실 0.03
# | 에폭 16 |  반복 121 / 351 | 시간 3[s] | 손실 0.03
# | 에폭 16 |  반복 141 / 351 | 시간 4[s] | 손실 0.04
# | 에폭 16 |  반복 161 / 351 | 시간 4[s] | 손실 0.04
# | 에폭 16 |  반복 181 / 351 | 시간 5[s] | 손실 0.04
# | 에폭 16 |  반복 201 / 351 | 시간 5[s] | 손실 0.04
# | 에폭 16 |  반복 221 / 351 | 시간 6[s] | 손실 0.04
# | 에폭 16 |  반복 241 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 16 |  반복 261 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 16 |  반복 281 / 351 | 시간 8[s] | 손실 0.05
# | 에폭 16 |  반복 301 / 351 | 시간 8[s] | 손실 0.05
# | 에폭 16 |  반복 321 / 351 | 시간 9[s] | 손실 0.04
# | 에폭 16 |  반복 341 / 351 | 시간 9[s] | 손실 0.06
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 92.020%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.06
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 17 |  반복 41 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 17 |  반복 61 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 17 |  반복 81 / 351 | 시간 2[s] | 손실 0.03
# | 에폭 17 |  반복 101 / 351 | 시간 2[s] | 손실 0.03
# | 에폭 17 |  반복 121 / 351 | 시간 3[s] | 손실 0.03
# | 에폭 17 |  반복 141 / 351 | 시간 4[s] | 손실 0.03
# | 에폭 17 |  반복 161 / 351 | 시간 4[s] | 손실 0.03
# | 에폭 17 |  반복 181 / 351 | 시간 5[s] | 손실 0.03
# | 에폭 17 |  반복 201 / 351 | 시간 5[s] | 손실 0.03
# | 에폭 17 |  반복 221 / 351 | 시간 6[s] | 손실 0.03
# | 에폭 17 |  반복 241 / 351 | 시간 7[s] | 손실 0.03
# | 에폭 17 |  반복 261 / 351 | 시간 7[s] | 손실 0.03
# | 에폭 17 |  반복 281 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 17 |  반복 301 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 17 |  반복 321 / 351 | 시간 9[s] | 손실 0.03
# | 에폭 17 |  반복 341 / 351 | 시간 9[s] | 손실 0.03
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# f:\Deep_Learning_From_Scratch2\20231003 - 7장_RNN을 사용한 문장 생성.ipynb Cell 9 line 4
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%207%EC%9E%A5_RNN%EC%9D%84%20%EC%82%AC%EC%9A%A9%ED%95%9C%20%EB%AC%B8%EC%9E%A5%20%EC%83%9D%EC%84%B1.ipynb#X11sZmlsZQ%3D%3D?line=37'>38</a>     question, correct = x_test[[i]], t_test[[i]]
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%207%EC%9E%A5_RNN%EC%9D%84%20%EC%82%AC%EC%9A%A9%ED%95%9C%20%EB%AC%B8%EC%9E%A5%20%EC%83%9D%EC%84%B1.ipynb#X11sZmlsZQ%3D%3D?line=38'>39</a>     verbose = i < 10
# ---> <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%207%EC%9E%A5_RNN%EC%9D%84%20%EC%82%AC%EC%9A%A9%ED%95%9C%20%EB%AC%B8%EC%9E%A5%20%EC%83%9D%EC%84%B1.ipynb#X11sZmlsZQ%3D%3D?line=39'>40</a>     correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%207%EC%9E%A5_RNN%EC%9D%84%20%EC%82%AC%EC%9A%A9%ED%95%9C%20%EB%AC%B8%EC%9E%A5%20%EC%83%9D%EC%84%B1.ipynb#X11sZmlsZQ%3D%3D?line=41'>42</a> acc = float(correct_num) / len(x_test)
#      <a href='vscode-notebook-cell:/f%3A/Deep_Learning_From_Scratch2/20231003%20-%207%EC%9E%A5_RNN%EC%9D%84%20%EC%82%AC%EC%9A%A9%ED%95%9C%20%EB%AC%B8%EC%9E%A5%20%EC%83%9D%EC%84%B1.ipynb#X11sZmlsZQ%3D%3D?line=42'>43</a> acc_list.append(acc)
#
# File f:\Deep_Learning_From_Scratch2\common\util.py:235, in eval_seq2seq(model, question, correct, id_to_char, verbos, is_reverse)
#     233 start_id = correct[0]
#     234 correct = correct[1:]
# --> 235 guess = model.generate(question, start_id, len(correct))
#     237 # 문자열로 변환
#     238 question = ''.join([id_to_char[int(c)] for c in question.flatten()])
#
# File f:\Deep_Learning_From_Scratch2\seq2seq.py:118, in Seq2seq.generate(self, xs, start_id, sample_size)
#     117 def generate(self, xs, start_id, sample_size):
# --> 118     h = self.encoder.forward(xs)
#     119     sampled = self.decoder.generate(h, start_id, sample_size)
#     120     return sampled
#
# File f:\Deep_Learning_From_Scratch2\seq2seq.py:27, in Encoder.forward(self, xs)
#      25 def forward(self, xs):
#      26     xs = self.embed.forward(xs)
# ---> 27     hs = self.lstm.forward(xs)
#      28     self.hs = hs
#      29     return hs[:, -1, :]
#
# File f:\Deep_Learning_From_Scratch2\common\time_layers.py:193, in TimeLSTM.forward(self, xs)
#     191 for t in range(T):
#     192     layer = LSTM(*self.params)
# --> 193     self.h, self.c = layer.forward(xs[:, t, :], self.h, self.c)
#     194     hs[:, t, :] = self.h
#     196     self.layers.append(layer)
#
# File f:\Deep_Learning_From_Scratch2\common\time_layers.py:114, in LSTM.forward(self, x, h_prev, c_prev)
#     111 Wx, Wh, b = self.params
#     112 N, H = h_prev.shape
# --> 114 A = np.dot(x, Wx) + np.dot(h_prev, Wh) + b
#     116 f = A[:, :H]
#     117 g = A[:, H:2*H]
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
